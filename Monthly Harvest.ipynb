# %%
# %matplotlib inline
from pprint import pprint
import itertools

from market import Returns_US_1871
from simulate import simulate_withdrawals
from harvesting import N_60_RebalanceHarvesting
from metrics import average, mean, median
from withdrawal import ConstantWithdrawals
import pandas

from adt import AnnualChange
import numpy

from scipy import stats

# %%
class Monthly_Returns_US_1871:
    def __init__(self, wrap=False):
        self.dataframe = pandas.read_csv('schiller_monthly.csv')
        self.years_of_data = len(self.dataframe)

    def __iter__(self):
        return self.iter_from(1871)

    def iter_from(self, year, length=None):
        start = (year * 12) - (1871 * 12)
        count = 0
        for row in self.dataframe.iloc[start:].iterrows():
            yield row[1]
            count += 1
            if length != None and count >= length:
                raise StopIteration

# %%
m = Monthly_Returns_US_1871()
count = 1
trigger = []

import datetime

def diff(x, y):
    (x_year, x_month) = map(lambda n: int(n), x.split('.'))
    (y_year, y_month) = map(lambda n: int(n), y.split('.'))

    dx = datetime.date(x_year, x_month, 1)
    dy = datetime.date(y_year, y_month, 1)
    return dy - dx

after_days = []

for (_, i) in m.dataframe.iloc[0:].iterrows():
    date = str(i['Date'])
    index = float(i['P'])

    if count == 1:
        start_of_year = index
        
        for (d, i) in trigger:
            if index >= i * 1.20:
                after_days.append(diff(d, date).days)
                print('Harvest %s in %s' % (d, date))
                trigger.remove((d,i))

        trigger.append((date, index))

    count += 1
    if count == 13:
        count = 1

print(numpy.std(after_days))
print(numpy.mean(after_days))
print(numpy.median(after_days))
# Out:
# Harvest 1877.01 in 1880.01
# Harvest 1879.01 in 1880.01
# Harvest 1871.01 in 1881.01
# Harvest 1873.01 in 1881.01
# Harvest 1875.01 in 1881.01
# Harvest 1878.01 in 1881.01
# Harvest 1872.01 in 1882.01
# Harvest 1876.01 in 1882.01
# Harvest 1874.01 in 1883.01
# Harvest 1885.01 in 1886.01
# Harvest 1891.01 in 1899.01
# Harvest 1894.01 in 1899.01
# Harvest 1896.01 in 1899.01
# Harvest 1898.01 in 1899.01
# Harvest 1895.01 in 1900.01
# Harvest 1880.01 in 1901.01
# Harvest 1883.01 in 1901.01
# Harvest 1886.01 in 1901.01
# Harvest 1888.01 in 1901.01
# Harvest 1890.01 in 1901.01
# Harvest 1893.01 in 1901.01
# Harvest 1881.01 in 1902.01
# Harvest 1884.01 in 1902.01
# Harvest 1889.01 in 1902.01
# Harvest 1897.01 in 1902.01
# Harvest 1900.01 in 1902.01
# Harvest 1882.01 in 1903.01
# Harvest 1892.01 in 1903.01
# Harvest 1887.01 in 1905.01
# Harvest 1904.01 in 1905.01
# Harvest 1899.01 in 1906.01
# Harvest 1902.01 in 1906.01
# Harvest 1901.01 in 1907.01
# Harvest 1908.01 in 1909.01
# Harvest 1915.01 in 1916.01
# Harvest 1918.01 in 1920.01
# Harvest 1921.01 in 1923.01
# Harvest 1922.01 in 1924.01
# Harvest 1903.01 in 1925.01
# Harvest 1914.01 in 1925.01
# Harvest 1919.01 in 1925.01
# Harvest 1905.01 in 1926.01
# Harvest 1907.01 in 1926.01
# Harvest 1910.01 in 1926.01
# Harvest 1912.01 in 1926.01
# Harvest 2005.01 in 2007.01
# Harvest 2004.01 in 2008.01
# Harvest 2009.01 in 2010.01
# Harvest 2010.01 in 2013.01
# Harvest 1999.01 in 2014.01
# Harvest 2001.01 in 2014.01
# Harvest 2007.01 in 2014.01
# Harvest 2011.01 in 2014.01
# Harvest 2013.01 in 2014.01
# Harvest 2000.01 in 2015.01
# Harvest 2008.01 in 2015.01
# Harvest 2006.01 in 2016.01
# 2223.02446985
# 2484.64084507
# 1461.0

# %%
after_days = []
count = 1

for (_, i) in m.dataframe.iloc[0:].iterrows():
    date = str(i['Date'])
    index = float(i['P'])
        
    for (d, i) in trigger:
        if index >= i * 1.20:
            after_days.append(diff(d, date).days)
            print('Harvest %s in %s' % (d, date))
            trigger.remove((d,i))

    if count == 1:
        trigger.append((date, index))

    count += 1
    if count == 13:
        count = 1

print(numpy.std(after_days))
print(numpy.mean(after_days))
print(numpy.median(after_days))
# Out:
# Harvest 1878.01 in 1879.05
# Harvest 1877.01 in 1879.1
# Harvest 1879.01 in 1879.11
# Harvest 1871.01 in 1880.1
# Harvest 1874.01 in 1880.11
# Harvest 1876.01 in 1880.11
# Harvest 1872.01 in 1880.12
# Harvest 1875.01 in 1880.12
# Harvest 1873.01 in 1881.01
# Harvest 1880.01 in 1881.02
# Harvest 1885.01 in 1885.11
# Harvest 1897.01 in 1898.07
# Harvest 1894.01 in 1898.08
# Harvest 1896.01 in 1898.08
# Harvest 1895.01 in 1898.09
# Harvest 1891.01 in 1899.01
# Harvest 1898.01 in 1899.01
# Harvest 1884.01 in 1899.02
# Harvest 1889.01 in 1899.02
# Harvest 1886.01 in 1899.03
# Harvest 1888.01 in 1899.03
# Harvest 1890.01 in 1899.04
# Harvest 1887.01 in 1900.12
# Harvest 1893.01 in 1900.12
# Harvest 1883.01 in 1901.01
# Harvest 1882.01 in 1901.02
# Harvest 1881.01 in 1901.03
# Harvest 1899.01 in 1901.03
# Harvest 1892.01 in 1901.04
# Harvest 1900.01 in 1901.05
# Harvest 1901.01 in 1901.06
# Harvest 1904.01 in 1904.11
# Harvest 1902.01 in 1906.01
# Harvest 1908.01 in 1908.08
# Harvest 1903.01 in 1909.08
# Harvest 1905.01 in 1909.09
# Harvest 1915.01 in 1915.1
# Harvest 1914.01 in 1916.11
# Harvest 1918.01 in 1919.05
# Harvest 1919.01 in 1919.07
# Harvest 1921.01 in 1922.08
# Harvest 1922.01 in 1922.09
# Harvest 1920.01 in 1925.02
# Harvest 1924.01 in 1925.02
# Harvest 1923.01 in 1925.06
# Harvest 1909.01 in 1925.07
# Harvest 1912.01 in 1925.07
# Harvest 1911.01 in 1925.08
# Harvest 1916.01 in 1925.08
# Harvest 1907.01 in 1925.09
# Harvest 1913.01 in 1925.09
# Harvest 1906.01 in 1925.1
# Harvest 1917.01 in 1925.1
# Harvest 1910.01 in 1925.11
# Harvest 1925.01 in 1926.08
# Harvest 1926.01 in 1927.07
# Harvest 1927.01 in 1927.09
# Harvest 1928.01 in 1928.09
# Harvest 1929.01 in 1929.08
# Harvest 1933.01 in 1933.05
# Harvest 1932.01 in 1933.06
# Harvest 1935.01 in 1935.08
# Harvest 1934.01 in 1935.11
# Harvest 1936.01 in 1936.1
# Harvest 1942.01 in 1943.03
# Harvest 1943.01 in 1943.07
# Harvest 1941.01 in 1944.06
# Harvest 1938.01 in 1945.02
# Harvest 1944.01 in 1945.04
# Harvest 1940.01 in 1945.05
# Harvest 1939.01 in 1945.06
# Harvest 1945.01 in 1945.1
# Harvest 1948.01 in 1950.04
# Harvest 1947.01 in 1950.05
# Harvest 1949.01 in 1950.06
# Harvest 1931.01 in 1950.1
# Harvest 1937.01 in 1951.01
# Harvest 1950.01 in 1951.01
# Harvest 1946.01 in 1951.02
# Harvest 1951.01 in 1952.12
# Harvest 1930.01 in 1953.01
# Harvest 1952.01 in 1954.07
# Harvest 1954.01 in 1954.08
# Harvest 1953.01 in 1954.09
# Harvest 1955.01 in 1955.09
# Harvest 1958.01 in 1958.1
# Harvest 1956.01 in 1958.12
# Harvest 1957.01 in 1959.01
# Harvest 1959.01 in 1961.08
# Harvest 1960.01 in 1961.11
# Harvest 1961.01 in 1961.12
# Harvest 1963.01 in 1964.03
# Harvest 1962.01 in 1964.07
# Harvest 1964.01 in 1965.11
# Harvest 1965.01 in 1968.1
# Harvest 1967.01 in 1968.1
# Harvest 1970.01 in 1972.04
# Harvest 1966.01 in 1972.11
# Harvest 1971.01 in 1972.11
# Harvest 1968.01 in 1972.12
# Harvest 1975.01 in 1975.05
# Harvest 1978.01 in 1979.09
# Harvest 1974.01 in 1980.07
# Harvest 1979.01 in 1980.07
# Harvest 1969.01 in 1980.08
# Harvest 1976.01 in 1980.08
# Harvest 1972.01 in 1980.09
# Harvest 1977.01 in 1980.09
# Harvest 1980.01 in 1980.11
# Harvest 1973.01 in 1983.01
# Harvest 1982.01 in 1983.01
# Harvest 1981.01 in 1983.05
# Harvest 1983.01 in 1985.02
# Harvest 1984.01 in 1985.12
# Harvest 1985.01 in 1986.01
# Harvest 1986.01 in 1987.01
# Harvest 1987.01 in 1987.08
# Harvest 1988.01 in 1989.04
# Harvest 1989.01 in 1989.08
# Harvest 1990.01 in 1992.01
# Harvest 1991.01 in 1992.02
# Harvest 1992.01 in 1995.04
# Harvest 1993.01 in 1995.05
# Harvest 1995.01 in 1995.08
# Harvest 1994.01 in 1995.09
# Harvest 1996.01 in 1996.12
# Harvest 1997.01 in 1997.07
# Harvest 1998.01 in 1998.07
# Harvest 2003.01 in 2003.12
# Harvest 2004.01 in 2006.1
# Harvest 2002.01 in 2006.11
# Harvest 2005.01 in 2007.01
# Harvest 1999.01 in 2007.05
# Harvest 2006.01 in 2007.1
# Harvest 2009.01 in 2009.09
# Harvest 2010.01 in 2012.02
# Harvest 2011.01 in 2013.03
# Harvest 2012.01 in 2013.04
# Harvest 2012.01 in 2013.04
# Harvest 2001.01 in 2013.05
# Harvest 2008.01 in 2013.07
# Harvest 2000.01 in 2013.1
# Harvest 2007.01 in 2013.11
# Harvest 2013.01 in 2013.12
# 1911.21296422
# 1693.13888889
# 761.5
