# %%
import numpy
from collections import deque
import pandas
import math
import pandas_datareader.data as web
import datetime
import requests
import requests_cache
import xlrd
import tempfile

# %%
def get_fred(fred_series):
    expire_after = datetime.timedelta(days=3)
    session = requests_cache.CachedSession(cache_name='data-cache', backend='sqlite', expire_after=expire_after)
    
    start = datetime.datetime(1800, 1, 1)
    df = web.DataReader(fred_series, "fred", start, session=session)
    return df

# All FRED data can be found at https://fred.stlouisfed.org/series/SERIES_NAME
FRED_SERIES = [
    'M1329AUSM193NNBR', # 1920-1934: Yields on Short-Term United States Securities, Three-Six Month Treasury Notes and Certificates, Three Month Treasury Bills for United States
    'M1329BUSM193NNBR', # 1931-1969: Yields on Short-Term United States Securities, Three-Six Month Treasury Notes and Certificates, Three Month Treasury Bills for United States
    'M13009USM156NNBR', # 1914-1969: Discount Rates, Federal Reserve Bank of New York for United States
    'M13044USM156NNBR', # 1951-1967: Yields on Corporate Bonds, New Issues, Aa Rating for United States
    'M13035USM156NNBR', # 1919-1968: Yields on Corporate Bonds, Highest Rating for United States
    'M1333AUSM156NNBR', # 1919-1944: Yield on Long-Term United States Bonds for United States
    'M13058USM156NNBR', # 1942-1962: Yields on Twenty Year United States Government Bonds for United States
    'BAA', # 1919-2016
    'AAA', # 1919-2016
    'CP1M', # 1971-1997
    'CP3M', # 1971-1997
    'CP6M', # 1970-1997
    'GS1M', # 2001-: 1-Month Treasury Constant Maturity Rate
    'GS3M', # 1982- : 3-Month Treasury Constant Maturity Rate
    'GS6M', # 1982- : 6-Month Treasury Constant Maturity Rate
    'GS1', # 1953-
    'GS2', # 1976-
    'GS3', # 1953-
    'GS5', # 1953-
    'GS7', # 1969-
    'GS10', # 1953-
    'GS20', # 1953-
    'GS30', # 1977-
    'CD1M', # 1965-2013
    'CD3M', # 1964-2013
    'CD6M', # 1964-2013
    'TB1YR', # 1959- (with gaps)
    'TB4WK', # 2001-
    'TB3MS', # 1934-
    'TB6MS', # 1958-
    'MSLB20', # 1953-216 State and Local Bonds - Bond Buyer Go 20-Bond Municipal Bond Index (DISCONTINUED)
    'LTGOVTBD', # 1925-2000 Long-Term U.S. Government Securities (DISCONTINUED)
]

fred = get_fred(FRED_SERIES)
fred.head()
# Out:
#             M1329AUSM193NNBR  M1329BUSM193NNBR  M13009USM156NNBR  \
# DATE
# 1914-11-01               NaN               NaN              5.75
# 1914-12-01               NaN               NaN              5.40
# 1915-01-01               NaN               NaN              4.75
# 1915-02-01               NaN               NaN              4.19
# 1915-03-01               NaN               NaN              4.00
#
#             M13044USM156NNBR  M13035USM156NNBR  M1333AUSM156NNBR  \
# DATE
# 1914-11-01               NaN               NaN               NaN
# 1914-12-01               NaN               NaN               NaN
# 1915-01-01               NaN               NaN               NaN
# 1915-02-01               NaN               NaN               NaN
# 1915-03-01               NaN               NaN               NaN
#
#             M13058USM156NNBR  BAA  AAA  CP1M    ...     GS30  CD1M  CD3M  \
# DATE                                            ...
# 1914-11-01               NaN  NaN  NaN   NaN    ...      NaN   NaN   NaN
# 1914-12-01               NaN  NaN  NaN   NaN    ...      NaN   NaN   NaN
# 1915-01-01               NaN  NaN  NaN   NaN    ...      NaN   NaN   NaN
# 1915-02-01               NaN  NaN  NaN   NaN    ...      NaN   NaN   NaN
# 1915-03-01               NaN  NaN  NaN   NaN    ...      NaN   NaN   NaN
#
#             CD6M  TB1YR  TB4WK  TB3MS  TB6MS  MSLB20  LTGOVTBD
# DATE
# 1914-11-01   NaN    NaN    NaN    NaN    NaN     NaN       NaN
# 1914-12-01   NaN    NaN    NaN    NaN    NaN     NaN       NaN
# 1915-01-01   NaN    NaN    NaN    NaN    NaN     NaN       NaN
# 1915-02-01   NaN    NaN    NaN    NaN    NaN     NaN       NaN
# 1915-03-01   NaN    NaN    NaN    NaN    NaN     NaN       NaN
#
# [5 rows x 32 columns]

# %%
def shiller_date_converter(x):
    year = int(x)
    month = int(x * 100) - (year * 100)
    dx = datetime.date(year, month, 1)
    return dx

def get_shiller(url="http://www.econ.yale.edu/~shiller/data/ie_data.xls"):
    expire_after = datetime.timedelta(days=3)
    session = requests_cache.CachedSession(cache_name='data-cache', backend='sqlite', expire_after=expire_after)

    r = session.get(url, stream=True)

    with tempfile.NamedTemporaryFile(suffix='.xls') as tmp:
        for chunk in r.iter_content(chunk_size=1024):
            tmp.write(chunk)
            
        tmp.flush()

        df = pandas.read_excel(tmp.name,
                               sheetname='Data',
                               engine='xlrd',
                               skiprows=7,
                               skipfooter=11, # WARN: is this always 11?
                               index_col=0,
                               parse_cols="A:E,G:K")
        df.rename(columns={'Price' : 'Real Price',
                          'Dividend' : 'Real Dividend',
                          'Earnings' : 'Real Earnings'}, inplace=True)
        # Convert from Shiller's wonky date format to a real one
        df.index = pandas.DatetimeIndex([shiller_date_converter(n) for n in df.index])
    return df

shiller = get_shiller()
shiller.head()
# Out:
#                P     D    E        CPI  Rate GS10  Real Price  Real Dividend  \
# 1871-01-01  4.44  0.26  0.4  12.464061   5.320000   86.190133       5.047170
# 1871-02-01  4.50  0.26  0.4  12.844641   5.323333   84.766585       4.897625
# 1871-03-01  4.61  0.26  0.4  13.034972   5.326667   85.570679       4.826112
# 1871-04-01  4.74  0.26  0.4  12.559226   5.330000   91.316573       5.008926
# 1871-05-01  4.86  0.26  0.4  12.273812   5.333333   95.805617       5.125403
#
#             Real Earnings  CAPE
# 1871-01-01       7.764877   NaN
# 1871-02-01       7.534808   NaN
# 1871-03-01       7.424788   NaN
# 1871-04-01       7.706040   NaN
# 1871-05-01       7.885236   NaN

# %%
def get_shiller_ch26(url='http://www.econ.yale.edu/~shiller/data/chapt26.xlsx'):
    expire_after = datetime.timedelta(days=3)
    session = requests_cache.CachedSession(cache_name='data-cache', backend='sqlite', expire_after=expire_after)

    r = session.get(url, stream=True)

    with tempfile.NamedTemporaryFile(suffix='.xls') as tmp:
        for chunk in r.iter_content(chunk_size=1024):
            tmp.write(chunk)
            
        tmp.flush()

        df = pandas.read_excel(tmp.name,
                               sheetname='Data',
                               engine='xlrd',
                               skiprows=7,
                               skipfooter=12, # WARN: is this always 12?
                               index_col=0,
                               parse_cols="A,E")
        df.rename(columns={'Unnamed: 1': 'One-Year Interest Rate'}, inplace=True)
        df.index = pandas.DatetimeIndex([datetime.date(n, 1, 1) for n in df.index])
    return df

SHILLER_CHAPTER_26 = get_shiller_ch26()
SHILLER_CHAPTER_26.head()
# Out:
#             One-Year Interest Rate
# 1871-01-01                    6.35
# 1872-01-01                    7.81
# 1873-01-01                    8.35
# 1874-01-01                    6.86
# 1875-01-01                    4.96

# %%
# Mix all of our data sources together!
all_by_month = pandas.concat([shiller, fred, SHILLER_CHAPTER_26], axis=1, join='outer')

# %%
# We only have annual interest rates from Shiller. We need to interpolate monthly rates...
all_by_month['One-Year Interest Rate'].interpolate(inplace=True)

# %%
def iterate_fund(ladder, yield_curve, max_maturity):
    ladder.reduce_maturities()
    ladder.generate_payments()
    sold_bonds = ladder.sell_bonds(yield_curve)

    # TODO: We don't ALWAYS buy a new bond...sometimes we hold on to the cash.
    new_bond = Bond(ladder.cash, yield_curve[max_maturity-1], max_maturity)
    ladder.cash = 0
    ladder.add_bond(new_bond)
    
    # This happens *after* we sell the shortest bond and buy a new long one
    # (at least, that's what longinvest does...)
    nav = ladder.get_nav(yield_curve)

    return (ladder, nav)

# %%
def a2m(annual_rate):
    return pow(annual_rate + 1, 1/12) - 1

class Bond:
    def __init__(self, face_value, yield_pct, maturity):
        self.face_value = face_value
        self.yield_pct = yield_pct
        self.maturity = maturity
        
    def __repr__(self):
        return ('Maturity: %d | Yield: %.2f%% | Face Value: $%.2f' % (self.maturity, self.yield_pct * 100, self.face_value))

    def gen_payment(self):
        return self.face_value * a2m(self.yield_pct)
    
    def value(self, rates):
        value = numpy.pv(a2m(rates[self.maturity - 1]), self.maturity, self.gen_payment(), self.face_value)
        return -value
    
class BondLadder:
    def __init__(self, min_maturity, max_maturity):
        self.min_maturity = min_maturity
        self.max_maturity = max_maturity
        self.cash = 0
        
        self.ladder = set()
        
    def get_nav(self, rates):
        return sum((b.value(rates) for b in self.ladder))

    def generate_payments(self):
        self.cash += sum((b.gen_payment() for b in self.ladder))        
        
    def __repr__(self):
        return ('%d-%d Ladder { Num Bonds: %d. }' % (self.max_maturity, self.min_maturity, len(self.ladder)))
        
    def add_bond(self, bond):
        assert bond.maturity <= self.max_maturity
        assert bond.maturity >= self.min_maturity
        self.ladder.add(bond)
    
    def reduce_maturities(self):
        for bond in self.ladder:
            bond.maturity -= 1

    def sell_bonds(self, rates):
        to_sell = filter(lambda bond: bond.maturity < self.min_maturity, self.ladder)
        to_sell = list(to_sell)
        self.ladder = self.ladder.difference(to_sell)
        self.cash += sum((b.value(rates) for b in to_sell))
        return to_sell

# %%
def bootstrap(yield_curve, max_bonds, min_maturity):
    bond_yield = yield_curve[max_bonds - 1]
    ladder = BondLadder(min_maturity, max_bonds)
    starting_face_value = 50 # chosen arbitrarily (to match longinvest)

    for i, j in zip(range(max_bonds), range(min_maturity, max_bonds+1)):
        face_value = pow(1 + a2m(bond_yield), i) * starting_face_value
        b = Bond(face_value, bond_yield, j)
        ladder.add_bond(b)
    return ladder
bootstrap([.0532]*120, 120, 108)
# Out:
# 120-108 Ladder { Num Bonds: 13. }

# %%
def splice_data(raw_rates, series):
    # Start by loading the data we get from Shiller.
    # This will always exist.

    def safe_add(series_index, rate_index):
        # Don't overwrite any data we already have.
        if math.isnan(series.iloc[series_index]):
            series.iloc[series_index] = raw_rates[rate_index]

    safe_add(1 * 12 - 1, 'GS1')
    safe_add(1 * 12 - 1, 'One-Year Interest Rate')
    safe_add(10 * 12 - 1, 'Rate GS10')

    safe_add(2 * 12 - 1, 'GS2')
    safe_add(3 * 12 - 1, 'GS3')
    safe_add(5 * 12 - 1, 'GS5')
    safe_add(7 * 12 - 1, 'GS7')

    safe_add(0, 'TB4WK')
    safe_add(0, 'CD1M')

    safe_add(3 - 1, 'TB3MS')
    safe_add(3 - 1, 'M1329AUSM193NNBR')

    safe_add(6 - 1, 'TB6MS')

def build_yield_curve(raw_rates, yield_curve_size=10*12):
    s = pandas.Series(math.nan, index=numpy.arange(yield_curve_size))

    # We use NaN to indicate "the data needs to be interpolated"
    # We have a few different data series that we splice together.
    splice_data(raw_rates, s)
    
    # This will do linear interpolation where it can.
    s.interpolate(inplace=True)
    
    # But it can still leave us with NaNs at the low end of the range
    s.fillna(method='backfill', inplace=True)
    
    # all of the data is in the form 3.71 but we want it to be .0371,
    # since that's what a percent actually is
    return s.apply(lambda x: x / 100).tolist()

# %%
['%.3f' % (s*100) for s in build_yield_curve(all_by_month.iloc[0])]
# Out:
# ['6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.350',
#  '6.340',
#  '6.331',
#  '6.321',
#  '6.312',
#  '6.302',
#  '6.293',
#  '6.283',
#  '6.274',
#  '6.264',
#  '6.255',
#  '6.245',
#  '6.236',
#  '6.226',
#  '6.216',
#  '6.207',
#  '6.197',
#  '6.188',
#  '6.178',
#  '6.169',
#  '6.159',
#  '6.150',
#  '6.140',
#  '6.131',
#  '6.121',
#  '6.112',
#  '6.102',
#  '6.092',
#  '6.083',
#  '6.073',
#  '6.064',
#  '6.054',
#  '6.045',
#  '6.035',
#  '6.026',
#  '6.016',
#  '6.007',
#  '5.997',
#  '5.988',
#  '5.978',
#  '5.969',
#  '5.959',
#  '5.949',
#  '5.940',
#  '5.930',
#  '5.921',
#  '5.911',
#  '5.902',
#  '5.892',
#  '5.883',
#  '5.873',
#  '5.864',
#  '5.854',
#  '5.845',
#  '5.835',
#  '5.825',
#  '5.816',
#  '5.806',
#  '5.797',
#  '5.787',
#  '5.778',
#  '5.768',
#  '5.759',
#  '5.749',
#  '5.740',
#  '5.730',
#  '5.721',
#  '5.711',
#  '5.701',
#  '5.692',
#  '5.682',
#  '5.673',
#  '5.663',
#  '5.654',
#  '5.644',
#  '5.635',
#  '5.625',
#  '5.616',
#  '5.606',
#  '5.597',
#  '5.587',
#  '5.578',
#  '5.568',
#  '5.558',
#  '5.549',
#  '5.539',
#  '5.530',
#  '5.520',
#  '5.511',
#  '5.501',
#  '5.492',
#  '5.482',
#  '5.473',
#  '5.463',
#  '5.454',
#  '5.444',
#  '5.434',
#  '5.425',
#  '5.415',
#  '5.406',
#  '5.396',
#  '5.387',
#  '5.377',
#  '5.368',
#  '5.358',
#  '5.349',
#  '5.339',
#  '5.330',
#  '5.320']

# %%
bootstrap(build_yield_curve(all_by_month.iloc[-2]), 10 * 12, 4 * 12)
# Out:
# 120-48 Ladder { Num Bonds: 73. }

# %%
def loop(ladder, rates, max_maturity):
    df = pandas.DataFrame(columns=['NAV', 'Change'])

    for (year, current_rates) in rates:
        print('Calculating...', year)
        (ladder, nav) = iterate_fund(ladder, build_yield_curve(current_rates), max_maturity)
        df.loc[year] = {'NAV' : nav, 'Change' : None}

    calculate_returns(df)
    return df

def calculate_returns(df):
    # Longinvest calculates the return based on comparison's to
    # next year's NAV. So I'll do the same. Even though that seems
    # weird to me. Maybe it's because the rates are based on January?
    # Hmmm...that sounds plausible.
    max_row = df.shape[0]

    for i in range(max_row - 1):
        next_nav = df.iloc[i+1]['NAV']
        nav = df.iloc[i]['NAV']
        change = (next_nav - nav) / nav
        df.iloc[i]['Change'] = change
    return df

def simulate(max_maturity, min_maturity, rates):
    """ This is just something to save on typing...and make clearer what the bounds on the fund are """
    ladder = bootstrap(build_yield_curve(rates.iloc[0]), max_maturity, min_maturity)
    return loop(ladder, rates.iterrows(), max_maturity)

# %%
# %%time
sim_results = simulate(10 * 12, 4 * 12, all_by_month)
print(sim_results.head())
# Out:
# Calculating... 1871-01-01 00:00:00
# Calculating... 1871-02-01 00:00:00
# Calculating... 1871-03-01 00:00:00
# Calculating... 1871-04-01 00:00:00
# Calculating... 1871-05-01 00:00:00
# Calculating... 1871-06-01 00:00:00
# Calculating... 1871-07-01 00:00:00
# Calculating... 1871-08-01 00:00:00
# Calculating... 1871-09-01 00:00:00
# Calculating... 1871-10-01 00:00:00
# Calculating... 1871-11-01 00:00:00
# Calculating... 1871-12-01 00:00:00
# Calculating... 1872-01-01 00:00:00
# Calculating... 1872-02-01 00:00:00
# Calculating... 1872-03-01 00:00:00
# Calculating... 1872-04-01 00:00:00
# Calculating... 1872-05-01 00:00:00
# Calculating... 1872-06-01 00:00:00
# Calculating... 1872-07-01 00:00:00
# Calculating... 1872-08-01 00:00:00
# Calculating... 1872-09-01 00:00:00
# Calculating... 1872-10-01 00:00:00
# Calculating... 1872-11-01 00:00:00
# Calculating... 1872-12-01 00:00:00
# Calculating... 1873-01-01 00:00:00
# Calculating... 1873-02-01 00:00:00
# Calculating... 1873-03-01 00:00:00
# Calculating... 1873-04-01 00:00:00
# Calculating... 1873-05-01 00:00:00
# Calculating... 1873-06-01 00:00:00
# Calculating... 1873-07-01 00:00:00
# Calculating... 1873-08-01 00:00:00
# Calculating... 1873-09-01 00:00:00
# Calculating... 1873-10-01 00:00:00
# Calculating... 1873-11-01 00:00:00
# Calculating... 1873-12-01 00:00:00
# Calculating... 1874-01-01 00:00:00
# Calculating... 1874-02-01 00:00:00
# Calculating... 1874-03-01 00:00:00
# Calculating... 1874-04-01 00:00:00
# Calculating... 1874-05-01 00:00:00
# Calculating... 1874-06-01 00:00:00
# Calculating... 1874-07-01 00:00:00
# Calculating... 1874-08-01 00:00:00
# Calculating... 1874-09-01 00:00:00
# Calculating... 1874-10-01 00:00:00
# Calculating... 1874-11-01 00:00:00
# Calculating... 1874-12-01 00:00:00
# Calculating... 1875-01-01 00:00:00
# Calculating... 1875-02-01 00:00:00
# Calculating... 1875-03-01 00:00:00
# Calculating... 1875-04-01 00:00:00
# Calculating... 1875-05-01 00:00:00
# Calculating... 1875-06-01 00:00:00
# Calculating... 1875-07-01 00:00:00
# Calculating... 1875-08-01 00:00:00
# Calculating... 1875-09-01 00:00:00
# Calculating... 1875-10-01 00:00:00
# Calculating... 1875-11-01 00:00:00
# Calculating... 1875-12-01 00:00:00
# Calculating... 1876-01-01 00:00:00
# Calculating... 1876-02-01 00:00:00
# Calculating... 1876-03-01 00:00:00
# Calculating... 1876-04-01 00:00:00
# Calculating... 1876-05-01 00:00:00
# Calculating... 1876-06-01 00:00:00
# Calculating... 1876-07-01 00:00:00
# Calculating... 1876-08-01 00:00:00
# Calculating... 1876-09-01 00:00:00
# Calculating... 1876-10-01 00:00:00
# Calculating... 1876-11-01 00:00:00
# Calculating... 1876-12-01 00:00:00
# Calculating... 1877-01-01 00:00:00
# Calculating... 1877-02-01 00:00:00
# Calculating... 1877-03-01 00:00:00
# Calculating... 1877-04-01 00:00:00
# Calculating... 1877-05-01 00:00:00
# Calculating... 1877-06-01 00:00:00
# Calculating... 1877-07-01 00:00:00
# Calculating... 1877-08-01 00:00:00
# Calculating... 1877-09-01 00:00:00
# Calculating... 1877-10-01 00:00:00
# Calculating... 1877-11-01 00:00:00
# Calculating... 1877-12-01 00:00:00
# Calculating... 1878-01-01 00:00:00
# Calculating... 1878-02-01 00:00:00
# Calculating... 1878-03-01 00:00:00
# Calculating... 1878-04-01 00:00:00
# Calculating... 1878-05-01 00:00:00
# Calculating... 1878-06-01 00:00:00
# Calculating... 1878-07-01 00:00:00
# Calculating... 1878-08-01 00:00:00
# Calculating... 1878-09-01 00:00:00
# Calculating... 1878-10-01 00:00:00
# Calculating... 1878-11-01 00:00:00
# Calculating... 1878-12-01 00:00:00
# Calculating... 1879-01-01 00:00:00
# Calculating... 1879-02-01 00:00:00
# Calculating... 1879-03-01 00:00:00
# Calculating... 1879-04-01 00:00:00
# Calculating... 1879-05-01 00:00:00
# Calculating... 1879-06-01 00:00:00
# Calculating... 1879-07-01 00:00:00
# Calculating... 1879-08-01 00:00:00
# Calculating... 1879-09-01 00:00:00
# Calculating... 1879-10-01 00:00:00
# Calculating... 1879-11-01 00:00:00
# Calculating... 1879-12-01 00:00:00
# Calculating... 1880-01-01 00:00:00
# Calculating... 1880-02-01 00:00:00
# Calculating... 1880-03-01 00:00:00
# Calculating... 1880-04-01 00:00:00
# Calculating... 1880-05-01 00:00:00
# Calculating... 1880-06-01 00:00:00
# Calculating... 1880-07-01 00:00:00
# Calculating... 1880-08-01 00:00:00
# Calculating... 1880-09-01 00:00:00
# Calculating... 1880-10-01 00:00:00
# Calculating... 1880-11-01 00:00:00
# Calculating... 1880-12-01 00:00:00
# Calculating... 1881-01-01 00:00:00
# Calculating... 1881-02-01 00:00:00
# Calculating... 1881-03-01 00:00:00
# Calculating... 1881-04-01 00:00:00
# Calculating... 1881-05-01 00:00:00
# Calculating... 1881-06-01 00:00:00
# Calculating... 1881-07-01 00:00:00
# Calculating... 1881-08-01 00:00:00
# Calculating... 1881-09-01 00:00:00
# Calculating... 1881-10-01 00:00:00
# Calculating... 1881-11-01 00:00:00
# Calculating... 1881-12-01 00:00:00
# Calculating... 1882-01-01 00:00:00
# Calculating... 1882-02-01 00:00:00
# Calculating... 1882-03-01 00:00:00
# Calculating... 1882-04-01 00:00:00
# Calculating... 1882-05-01 00:00:00
# Calculating... 1882-06-01 00:00:00
# Calculating... 1882-07-01 00:00:00
# Calculating... 1882-08-01 00:00:00
# Calculating... 1882-09-01 00:00:00
# Calculating... 1882-10-01 00:00:00
# Calculating... 1882-11-01 00:00:00
# Calculating... 1882-12-01 00:00:00
# Calculating... 1883-01-01 00:00:00
# Calculating... 1883-02-01 00:00:00
# Calculating... 1883-03-01 00:00:00
# Calculating... 1883-04-01 00:00:00
# Calculating... 1883-05-01 00:00:00
# Calculating... 1883-06-01 00:00:00
# Calculating... 1883-07-01 00:00:00
# Calculating... 1883-08-01 00:00:00
# Calculating... 1883-09-01 00:00:00
# Calculating... 1883-10-01 00:00:00
# Calculating... 1883-11-01 00:00:00
# Calculating... 1883-12-01 00:00:00
# Calculating... 1884-01-01 00:00:00
# Calculating... 1884-02-01 00:00:00
# Calculating... 1884-03-01 00:00:00
# Calculating... 1884-04-01 00:00:00
# Calculating... 1884-05-01 00:00:00
# Calculating... 1884-06-01 00:00:00
# Calculating... 1884-07-01 00:00:00
# Calculating... 1884-08-01 00:00:00
# Calculating... 1884-09-01 00:00:00
# Calculating... 1884-10-01 00:00:00
# Calculating... 1884-11-01 00:00:00
# Calculating... 1884-12-01 00:00:00
# Calculating... 1885-01-01 00:00:00
# Calculating... 1885-02-01 00:00:00
# Calculating... 1885-03-01 00:00:00
# Calculating... 1885-04-01 00:00:00
# Calculating... 1885-05-01 00:00:00
# Calculating... 1885-06-01 00:00:00
# Calculating... 1885-07-01 00:00:00
# Calculating... 1885-08-01 00:00:00
# Calculating... 1885-09-01 00:00:00
# Calculating... 1885-10-01 00:00:00
# Calculating... 1885-11-01 00:00:00
# Calculating... 1885-12-01 00:00:00
# Calculating... 1886-01-01 00:00:00
# Calculating... 1886-02-01 00:00:00
# Calculating... 1886-03-01 00:00:00
# Calculating... 1886-04-01 00:00:00
# Calculating... 1886-05-01 00:00:00
# Calculating... 1886-06-01 00:00:00
# Calculating... 1886-07-01 00:00:00
# Calculating... 1886-08-01 00:00:00
# Calculating... 1886-09-01 00:00:00
# Calculating... 1886-10-01 00:00:00
# Calculating... 1886-11-01 00:00:00
# Calculating... 1886-12-01 00:00:00
# Calculating... 1887-01-01 00:00:00
# Calculating... 1887-02-01 00:00:00
# Calculating... 1887-03-01 00:00:00
# Calculating... 1887-04-01 00:00:00
# Calculating... 1887-05-01 00:00:00
# Calculating... 1887-06-01 00:00:00
# Calculating... 1887-07-01 00:00:00
# Calculating... 1887-08-01 00:00:00
# Calculating... 1887-09-01 00:00:00
# Calculating... 1887-10-01 00:00:00
# Calculating... 1887-11-01 00:00:00
# Calculating... 1887-12-01 00:00:00
# Calculating... 1888-01-01 00:00:00
# Calculating... 1888-02-01 00:00:00
# Calculating... 1888-03-01 00:00:00
# Calculating... 1888-04-01 00:00:00
# Calculating... 1888-05-01 00:00:00
# Calculating... 1888-06-01 00:00:00
# Calculating... 1888-07-01 00:00:00
# Calculating... 1888-08-01 00:00:00
# Calculating... 1888-09-01 00:00:00
# Calculating... 1888-10-01 00:00:00
# Calculating... 1888-11-01 00:00:00
# Calculating... 1888-12-01 00:00:00
# Calculating... 1889-01-01 00:00:00
# Calculating... 1889-02-01 00:00:00
# Calculating... 1889-03-01 00:00:00
# Calculating... 1889-04-01 00:00:00
# Calculating... 1889-05-01 00:00:00
# Calculating... 1889-06-01 00:00:00
# Calculating... 1889-07-01 00:00:00
# Calculating... 1889-08-01 00:00:00
# Calculating... 1889-09-01 00:00:00
# Calculating... 1889-10-01 00:00:00
# Calculating... 1889-11-01 00:00:00
# Calculating... 1889-12-01 00:00:00
# Calculating... 1890-01-01 00:00:00
# Calculating... 1890-02-01 00:00:00
# Calculating... 1890-03-01 00:00:00
# Calculating... 1890-04-01 00:00:00
# Calculating... 1890-05-01 00:00:00
# Calculating... 1890-06-01 00:00:00
# Calculating... 1890-07-01 00:00:00
# Calculating... 1890-08-01 00:00:00
# Calculating... 1890-09-01 00:00:00
# Calculating... 1890-10-01 00:00:00
# Calculating... 1890-11-01 00:00:00
# Calculating... 1890-12-01 00:00:00
# Calculating... 1891-01-01 00:00:00
# Calculating... 1891-02-01 00:00:00
# Calculating... 1891-03-01 00:00:00
# Calculating... 1891-04-01 00:00:00
# Calculating... 1891-05-01 00:00:00
# Calculating... 1891-06-01 00:00:00
# Calculating... 1891-07-01 00:00:00
# Calculating... 1891-08-01 00:00:00
# Calculating... 1891-09-01 00:00:00
# Calculating... 1891-10-01 00:00:00
# Calculating... 1891-11-01 00:00:00
# Calculating... 1891-12-01 00:00:00
# Calculating... 1892-01-01 00:00:00
# Calculating... 1892-02-01 00:00:00
# Calculating... 1892-03-01 00:00:00
# Calculating... 1892-04-01 00:00:00
# Calculating... 1892-05-01 00:00:00
# Calculating... 1892-06-01 00:00:00
# Calculating... 1892-07-01 00:00:00
# Calculating... 1892-08-01 00:00:00
# Calculating... 1892-09-01 00:00:00
# Calculating... 1892-10-01 00:00:00
# Calculating... 1892-11-01 00:00:00
# Calculating... 1892-12-01 00:00:00
# Calculating... 1893-01-01 00:00:00
# Calculating... 1893-02-01 00:00:00
# Calculating... 1893-03-01 00:00:00
# Calculating... 1893-04-01 00:00:00
# Calculating... 1893-05-01 00:00:00
# Calculating... 1893-06-01 00:00:00
# Calculating... 1893-07-01 00:00:00
# Calculating... 1893-08-01 00:00:00
# Calculating... 1893-09-01 00:00:00
# Calculating... 1893-10-01 00:00:00
# Calculating... 1893-11-01 00:00:00
# Calculating... 1893-12-01 00:00:00
# Calculating... 1894-01-01 00:00:00
# Calculating... 1894-02-01 00:00:00
# Calculating... 1894-03-01 00:00:00
# Calculating... 1894-04-01 00:00:00
# Calculating... 1894-05-01 00:00:00
# Calculating... 1894-06-01 00:00:00
# Calculating... 1894-07-01 00:00:00
# Calculating... 1894-08-01 00:00:00
# Calculating... 1894-09-01 00:00:00
# Calculating... 1894-10-01 00:00:00
# Calculating... 1894-11-01 00:00:00
# Calculating... 1894-12-01 00:00:00
# Calculating... 1895-01-01 00:00:00
# Calculating... 1895-02-01 00:00:00
# Calculating... 1895-03-01 00:00:00
# Calculating... 1895-04-01 00:00:00
# Calculating... 1895-05-01 00:00:00
# Calculating... 1895-06-01 00:00:00
# Calculating... 1895-07-01 00:00:00
# Calculating... 1895-08-01 00:00:00
# Calculating... 1895-09-01 00:00:00
# Calculating... 1895-10-01 00:00:00
# Calculating... 1895-11-01 00:00:00
# Calculating... 1895-12-01 00:00:00
# Calculating... 1896-01-01 00:00:00
# Calculating... 1896-02-01 00:00:00
# Calculating... 1896-03-01 00:00:00
# Calculating... 1896-04-01 00:00:00
# Calculating... 1896-05-01 00:00:00
# Calculating... 1896-06-01 00:00:00
# Calculating... 1896-07-01 00:00:00
# Calculating... 1896-08-01 00:00:00
# Calculating... 1896-09-01 00:00:00
# Calculating... 1896-10-01 00:00:00
# Calculating... 1896-11-01 00:00:00
# Calculating... 1896-12-01 00:00:00
# Calculating... 1897-01-01 00:00:00
# Calculating... 1897-02-01 00:00:00
# Calculating... 1897-03-01 00:00:00
# Calculating... 1897-04-01 00:00:00
# Calculating... 1897-05-01 00:00:00
# Calculating... 1897-06-01 00:00:00
# Calculating... 1897-07-01 00:00:00
# Calculating... 1897-08-01 00:00:00
# Calculating... 1897-09-01 00:00:00
# Calculating... 1897-10-01 00:00:00
# Calculating... 1897-11-01 00:00:00
# Calculating... 1897-12-01 00:00:00
# Calculating... 1898-01-01 00:00:00
# Calculating... 1898-02-01 00:00:00
# Calculating... 1898-03-01 00:00:00
# Calculating... 1898-04-01 00:00:00
# Calculating... 1898-05-01 00:00:00
# Calculating... 1898-06-01 00:00:00
# Calculating... 1898-07-01 00:00:00
# Calculating... 1898-08-01 00:00:00
# Calculating... 1898-09-01 00:00:00
# Calculating... 1898-10-01 00:00:00
# Calculating... 1898-11-01 00:00:00
# Calculating... 1898-12-01 00:00:00
# Calculating... 1899-01-01 00:00:00
# Calculating... 1899-02-01 00:00:00
# Calculating... 1899-03-01 00:00:00
# Calculating... 1899-04-01 00:00:00
# Calculating... 1899-05-01 00:00:00
# Calculating... 1899-06-01 00:00:00
# Calculating... 1899-07-01 00:00:00
# Calculating... 1899-08-01 00:00:00
# Calculating... 1899-09-01 00:00:00
# Calculating... 1899-10-01 00:00:00
# Calculating... 1899-11-01 00:00:00
# Calculating... 1899-12-01 00:00:00
# Calculating... 1900-01-01 00:00:00
# Calculating... 1900-02-01 00:00:00
# Calculating... 1900-03-01 00:00:00
# Calculating... 1900-04-01 00:00:00
# Calculating... 1900-05-01 00:00:00
# Calculating... 1900-06-01 00:00:00
# Calculating... 1900-07-01 00:00:00
# Calculating... 1900-08-01 00:00:00
# Calculating... 1900-09-01 00:00:00
# Calculating... 1900-10-01 00:00:00
# Calculating... 1900-11-01 00:00:00
# Calculating... 1900-12-01 00:00:00
# Calculating... 1901-01-01 00:00:00
# Calculating... 1901-02-01 00:00:00
# Calculating... 1901-03-01 00:00:00
# Calculating... 1901-04-01 00:00:00
# Calculating... 1901-05-01 00:00:00
# Calculating... 1901-06-01 00:00:00
# Calculating... 1901-07-01 00:00:00
# Calculating... 1901-08-01 00:00:00
# Calculating... 1901-09-01 00:00:00
# Calculating... 1901-10-01 00:00:00
# Calculating... 1901-11-01 00:00:00
# Calculating... 1901-12-01 00:00:00
# Calculating... 1902-01-01 00:00:00
# Calculating... 1902-02-01 00:00:00
# Calculating... 1902-03-01 00:00:00
# Calculating... 1902-04-01 00:00:00
# Calculating... 1902-05-01 00:00:00
# Calculating... 1902-06-01 00:00:00
# Calculating... 1902-07-01 00:00:00
# Calculating... 1902-08-01 00:00:00
# Calculating... 1902-09-01 00:00:00
# Calculating... 1902-10-01 00:00:00
# Calculating... 1902-11-01 00:00:00
# Calculating... 1902-12-01 00:00:00
# Calculating... 1903-01-01 00:00:00
# Calculating... 1903-02-01 00:00:00
# Calculating... 1903-03-01 00:00:00
# Calculating... 1903-04-01 00:00:00
# Calculating... 1903-05-01 00:00:00
# Calculating... 1903-06-01 00:00:00
# Calculating... 1903-07-01 00:00:00
# Calculating... 1903-08-01 00:00:00
# Calculating... 1903-09-01 00:00:00
# Calculating... 1903-10-01 00:00:00
# Calculating... 1903-11-01 00:00:00
# Calculating... 1903-12-01 00:00:00
# Calculating... 1904-01-01 00:00:00
# Calculating... 1904-02-01 00:00:00
# Calculating... 1904-03-01 00:00:00
# Calculating... 1904-04-01 00:00:00
# Calculating... 1904-05-01 00:00:00
# Calculating... 1904-06-01 00:00:00
# Calculating... 1904-07-01 00:00:00
# Calculating... 1904-08-01 00:00:00
# Calculating... 1904-09-01 00:00:00
# Calculating... 1904-10-01 00:00:00
# Calculating... 1904-11-01 00:00:00
# Calculating... 1904-12-01 00:00:00
# Calculating... 1905-01-01 00:00:00
# Calculating... 1905-02-01 00:00:00
# Calculating... 1905-03-01 00:00:00
# Calculating... 1905-04-01 00:00:00
# Calculating... 1905-05-01 00:00:00
# Calculating... 1905-06-01 00:00:00
# Calculating... 1905-07-01 00:00:00
# Calculating... 1905-08-01 00:00:00
# Calculating... 1905-09-01 00:00:00
# Calculating... 1905-10-01 00:00:00
# Calculating... 1905-11-01 00:00:00
# Calculating... 1905-12-01 00:00:00
# Calculating... 1906-01-01 00:00:00
# Calculating... 1906-02-01 00:00:00
# Calculating... 1906-03-01 00:00:00
# Calculating... 1906-04-01 00:00:00
# Calculating... 1906-05-01 00:00:00
# Calculating... 1906-06-01 00:00:00
# Calculating... 1906-07-01 00:00:00
# Calculating... 1906-08-01 00:00:00
# Calculating... 1906-09-01 00:00:00
# Calculating... 1906-10-01 00:00:00
# Calculating... 1906-11-01 00:00:00
# Calculating... 1906-12-01 00:00:00
# Calculating... 1907-01-01 00:00:00
# Calculating... 1907-02-01 00:00:00
# Calculating... 1907-03-01 00:00:00
# Calculating... 1907-04-01 00:00:00
# Calculating... 1907-05-01 00:00:00
# Calculating... 1907-06-01 00:00:00
# Calculating... 1907-07-01 00:00:00
# Calculating... 1907-08-01 00:00:00
# Calculating... 1907-09-01 00:00:00
# Calculating... 1907-10-01 00:00:00
# Calculating... 1907-11-01 00:00:00
# Calculating... 1907-12-01 00:00:00
# Calculating... 1908-01-01 00:00:00
# Calculating... 1908-02-01 00:00:00
# Calculating... 1908-03-01 00:00:00
# Calculating... 1908-04-01 00:00:00
# Calculating... 1908-05-01 00:00:00
# Calculating... 1908-06-01 00:00:00
# Calculating... 1908-07-01 00:00:00
# Calculating... 1908-08-01 00:00:00
# Calculating... 1908-09-01 00:00:00
# Calculating... 1908-10-01 00:00:00
# Calculating... 1908-11-01 00:00:00
# Calculating... 1908-12-01 00:00:00
# Calculating... 1909-01-01 00:00:00
# Calculating... 1909-02-01 00:00:00
# Calculating... 1909-03-01 00:00:00
# Calculating... 1909-04-01 00:00:00
# Calculating... 1909-05-01 00:00:00
# Calculating... 1909-06-01 00:00:00
# Calculating... 1909-07-01 00:00:00
# Calculating... 1909-08-01 00:00:00
# Calculating... 1909-09-01 00:00:00
# Calculating... 1909-10-01 00:00:00
# Calculating... 1909-11-01 00:00:00
# Calculating... 1909-12-01 00:00:00
# Calculating... 1910-01-01 00:00:00
# Calculating... 1910-02-01 00:00:00
# Calculating... 1910-03-01 00:00:00
# Calculating... 1910-04-01 00:00:00
# Calculating... 1910-05-01 00:00:00
# Calculating... 1910-06-01 00:00:00
# Calculating... 1910-07-01 00:00:00
# Calculating... 1910-08-01 00:00:00
# Calculating... 1910-09-01 00:00:00
# Calculating... 1910-10-01 00:00:00
# Calculating... 1910-11-01 00:00:00
# Calculating... 1910-12-01 00:00:00
# Calculating... 1911-01-01 00:00:00
# Calculating... 1911-02-01 00:00:00
# Calculating... 1911-03-01 00:00:00
# Calculating... 1911-04-01 00:00:00
# Calculating... 1911-05-01 00:00:00
# Calculating... 1911-06-01 00:00:00
# Calculating... 1911-07-01 00:00:00
# Calculating... 1911-08-01 00:00:00
# Calculating... 1911-09-01 00:00:00
# Calculating... 1911-10-01 00:00:00
# Calculating... 1911-11-01 00:00:00
# Calculating... 1911-12-01 00:00:00
# Calculating... 1912-01-01 00:00:00
# Calculating... 1912-02-01 00:00:00
# Calculating... 1912-03-01 00:00:00
# Calculating... 1912-04-01 00:00:00
# Calculating... 1912-05-01 00:00:00
# Calculating... 1912-06-01 00:00:00
# Calculating... 1912-07-01 00:00:00
# Calculating... 1912-08-01 00:00:00
# Calculating... 1912-09-01 00:00:00
# Calculating... 1912-10-01 00:00:00
# Calculating... 1912-11-01 00:00:00
# Calculating... 1912-12-01 00:00:00
# Calculating... 1913-01-01 00:00:00
# Calculating... 1913-02-01 00:00:00
# Calculating... 1913-03-01 00:00:00
# Calculating... 1913-04-01 00:00:00
# Calculating... 1913-05-01 00:00:00
# Calculating... 1913-06-01 00:00:00
# Calculating... 1913-07-01 00:00:00
# Calculating... 1913-08-01 00:00:00
# Calculating... 1913-09-01 00:00:00
# Calculating... 1913-10-01 00:00:00
# Calculating... 1913-11-01 00:00:00
# Calculating... 1913-12-01 00:00:00
# Calculating... 1914-01-01 00:00:00
# Calculating... 1914-02-01 00:00:00
# Calculating... 1914-03-01 00:00:00
# Calculating... 1914-04-01 00:00:00
# Calculating... 1914-05-01 00:00:00
# Calculating... 1914-06-01 00:00:00
# Calculating... 1914-07-01 00:00:00
# Calculating... 1914-08-01 00:00:00
# Calculating... 1914-09-01 00:00:00
# Calculating... 1914-10-01 00:00:00
# Calculating... 1914-11-01 00:00:00
# Calculating... 1914-12-01 00:00:00
# Calculating... 1915-01-01 00:00:00
# Calculating... 1915-02-01 00:00:00
# Calculating... 1915-03-01 00:00:00
# Calculating... 1915-04-01 00:00:00
# Calculating... 1915-05-01 00:00:00
# Calculating... 1915-06-01 00:00:00
# Calculating... 1915-07-01 00:00:00
# Calculating... 1915-08-01 00:00:00
# Calculating... 1915-09-01 00:00:00
# Calculating... 1915-10-01 00:00:00
# Calculating... 1915-11-01 00:00:00
# Calculating... 1915-12-01 00:00:00
# Calculating... 1916-01-01 00:00:00
# Calculating... 1916-02-01 00:00:00
# Calculating... 1916-03-01 00:00:00
# Calculating... 1916-04-01 00:00:00
# Calculating... 1916-05-01 00:00:00
# Calculating... 1916-06-01 00:00:00
# Calculating... 1916-07-01 00:00:00
# Calculating... 1916-08-01 00:00:00
# Calculating... 1916-09-01 00:00:00
# Calculating... 1916-10-01 00:00:00
# Calculating... 1916-11-01 00:00:00
# Calculating... 1916-12-01 00:00:00
# Calculating... 1917-01-01 00:00:00
# Calculating... 1917-02-01 00:00:00
# Calculating... 1917-03-01 00:00:00
# Calculating... 1917-04-01 00:00:00
# Calculating... 1917-05-01 00:00:00
# Calculating... 1917-06-01 00:00:00
# Calculating... 1917-07-01 00:00:00
# Calculating... 1917-08-01 00:00:00
# Calculating... 1917-09-01 00:00:00
# Calculating... 1917-10-01 00:00:00
# Calculating... 1917-11-01 00:00:00
# Calculating... 1917-12-01 00:00:00
# Calculating... 1918-01-01 00:00:00
# Calculating... 1918-02-01 00:00:00
# Calculating... 1918-03-01 00:00:00
# Calculating... 1918-04-01 00:00:00
# Calculating... 1918-05-01 00:00:00
# Calculating... 1918-06-01 00:00:00
# Calculating... 1918-07-01 00:00:00
# Calculating... 1918-08-01 00:00:00
# Calculating... 1918-09-01 00:00:00
# Calculating... 1918-10-01 00:00:00
# Calculating... 1918-11-01 00:00:00
# Calculating... 1918-12-01 00:00:00
# Calculating... 1919-01-01 00:00:00
# Calculating... 1919-02-01 00:00:00
# Calculating... 1919-03-01 00:00:00
# Calculating... 1919-04-01 00:00:00
# Calculating... 1919-05-01 00:00:00
# Calculating... 1919-06-01 00:00:00
# Calculating... 1919-07-01 00:00:00
# Calculating... 1919-08-01 00:00:00
# Calculating... 1919-09-01 00:00:00
# Calculating... 1919-10-01 00:00:00
# Calculating... 1919-11-01 00:00:00
# Calculating... 1919-12-01 00:00:00
# Calculating... 1920-01-01 00:00:00
# Calculating... 1920-02-01 00:00:00
# Calculating... 1920-03-01 00:00:00
# Calculating... 1920-04-01 00:00:00
# Calculating... 1920-05-01 00:00:00
# Calculating... 1920-06-01 00:00:00
# Calculating... 1920-07-01 00:00:00
# Calculating... 1920-08-01 00:00:00
# Calculating... 1920-09-01 00:00:00
# Calculating... 1920-10-01 00:00:00
# Calculating... 1920-11-01 00:00:00
# Calculating... 1920-12-01 00:00:00
# Calculating... 1921-01-01 00:00:00
# Calculating... 1921-02-01 00:00:00
# Calculating... 1921-03-01 00:00:00
# Calculating... 1921-04-01 00:00:00
# Calculating... 1921-05-01 00:00:00
# Calculating... 1921-06-01 00:00:00
# Calculating... 1921-07-01 00:00:00
# Calculating... 1921-08-01 00:00:00
# Calculating... 1921-09-01 00:00:00
# Calculating... 1921-10-01 00:00:00
# Calculating... 1921-11-01 00:00:00
# Calculating... 1921-12-01 00:00:00
# Calculating... 1922-01-01 00:00:00
# Calculating... 1922-02-01 00:00:00
# Calculating... 1922-03-01 00:00:00
# Calculating... 1922-04-01 00:00:00
# Calculating... 1922-05-01 00:00:00
# Calculating... 1922-06-01 00:00:00
# Calculating... 1922-07-01 00:00:00
# Calculating... 1922-08-01 00:00:00
# Calculating... 1922-09-01 00:00:00
# Calculating... 1922-10-01 00:00:00
# Calculating... 1922-11-01 00:00:00
# Calculating... 1922-12-01 00:00:00
# Calculating... 1923-01-01 00:00:00
# Calculating... 1923-02-01 00:00:00
# Calculating... 1923-03-01 00:00:00
# Calculating... 1923-04-01 00:00:00
# Calculating... 1923-05-01 00:00:00
# Calculating... 1923-06-01 00:00:00
# Calculating... 1923-07-01 00:00:00
# Calculating... 1923-08-01 00:00:00
# Calculating... 1923-09-01 00:00:00
# Calculating... 1923-10-01 00:00:00
# Calculating... 1923-11-01 00:00:00
# Calculating... 1923-12-01 00:00:00
# Calculating... 1924-01-01 00:00:00
# Calculating... 1924-02-01 00:00:00
# Calculating... 1924-03-01 00:00:00
# Calculating... 1924-04-01 00:00:00
# Calculating... 1924-05-01 00:00:00
# Calculating... 1924-06-01 00:00:00
# Calculating... 1924-07-01 00:00:00
# Calculating... 1924-08-01 00:00:00
# Calculating... 1924-09-01 00:00:00
# Calculating... 1924-10-01 00:00:00
# Calculating... 1924-11-01 00:00:00
# Calculating... 1924-12-01 00:00:00
# Calculating... 1925-01-01 00:00:00
# Calculating... 1925-02-01 00:00:00
# Calculating... 1925-03-01 00:00:00
# Calculating... 1925-04-01 00:00:00
# Calculating... 1925-05-01 00:00:00
# Calculating... 1925-06-01 00:00:00
# Calculating... 1925-07-01 00:00:00
# Calculating... 1925-08-01 00:00:00
# Calculating... 1925-09-01 00:00:00
# Calculating... 1925-10-01 00:00:00
# Calculating... 1925-11-01 00:00:00
# Calculating... 1925-12-01 00:00:00
# Calculating... 1926-01-01 00:00:00
# Calculating... 1926-02-01 00:00:00
# Calculating... 1926-03-01 00:00:00
# Calculating... 1926-04-01 00:00:00
# Calculating... 1926-05-01 00:00:00
# Calculating... 1926-06-01 00:00:00
# Calculating... 1926-07-01 00:00:00
# Calculating... 1926-08-01 00:00:00
# Calculating... 1926-09-01 00:00:00
# Calculating... 1926-10-01 00:00:00
# Calculating... 1926-11-01 00:00:00
# Calculating... 1926-12-01 00:00:00
# Calculating... 1927-01-01 00:00:00
# Calculating... 1927-02-01 00:00:00
# Calculating... 1927-03-01 00:00:00
# Calculating... 1927-04-01 00:00:00
# Calculating... 1927-05-01 00:00:00
# Calculating... 1927-06-01 00:00:00
# Calculating... 1927-07-01 00:00:00
# Calculating... 1927-08-01 00:00:00
# Calculating... 1927-09-01 00:00:00
# Calculating... 1927-10-01 00:00:00
# Calculating... 1927-11-01 00:00:00
# Calculating... 1927-12-01 00:00:00
# Calculating... 1928-01-01 00:00:00
# Calculating... 1928-02-01 00:00:00
# Calculating... 1928-03-01 00:00:00
# Calculating... 1928-04-01 00:00:00
# Calculating... 1928-05-01 00:00:00
# Calculating... 1928-06-01 00:00:00
# Calculating... 1928-07-01 00:00:00
# Calculating... 1928-08-01 00:00:00
# Calculating... 1928-09-01 00:00:00
# Calculating... 1928-10-01 00:00:00
# Calculating... 1928-11-01 00:00:00
# Calculating... 1928-12-01 00:00:00
# Calculating... 1929-01-01 00:00:00
# Calculating... 1929-02-01 00:00:00
# Calculating... 1929-03-01 00:00:00
# Calculating... 1929-04-01 00:00:00
# Calculating... 1929-05-01 00:00:00
# Calculating... 1929-06-01 00:00:00
# Calculating... 1929-07-01 00:00:00
# Calculating... 1929-08-01 00:00:00
# Calculating... 1929-09-01 00:00:00
# Calculating... 1929-10-01 00:00:00
# Calculating... 1929-11-01 00:00:00
# Calculating... 1929-12-01 00:00:00
# Calculating... 1930-01-01 00:00:00
# Calculating... 1930-02-01 00:00:00
# Calculating... 1930-03-01 00:00:00
# Calculating... 1930-04-01 00:00:00
# Calculating... 1930-05-01 00:00:00
# Calculating... 1930-06-01 00:00:00
# Calculating... 1930-07-01 00:00:00
# Calculating... 1930-08-01 00:00:00
# Calculating... 1930-09-01 00:00:00
# Calculating... 1930-10-01 00:00:00
# Calculating... 1930-11-01 00:00:00
# Calculating... 1930-12-01 00:00:00
# Calculating... 1931-01-01 00:00:00
# Calculating... 1931-02-01 00:00:00
# Calculating... 1931-03-01 00:00:00
# Calculating... 1931-04-01 00:00:00
# Calculating... 1931-05-01 00:00:00
# Calculating... 1931-06-01 00:00:00
# Calculating... 1931-07-01 00:00:00
# Calculating... 1931-08-01 00:00:00
# Calculating... 1931-09-01 00:00:00
# Calculating... 1931-10-01 00:00:00
# Calculating... 1931-11-01 00:00:00
# Calculating... 1931-12-01 00:00:00
# Calculating... 1932-01-01 00:00:00
# Calculating... 1932-02-01 00:00:00
# Calculating... 1932-03-01 00:00:00
# Calculating... 1932-04-01 00:00:00
# Calculating... 1932-05-01 00:00:00
# Calculating... 1932-06-01 00:00:00
# Calculating... 1932-07-01 00:00:00
# Calculating... 1932-08-01 00:00:00
# Calculating... 1932-09-01 00:00:00
# Calculating... 1932-10-01 00:00:00
# Calculating... 1932-11-01 00:00:00
# Calculating... 1932-12-01 00:00:00
# Calculating... 1933-01-01 00:00:00
# Calculating... 1933-02-01 00:00:00
# Calculating... 1933-03-01 00:00:00
# Calculating... 1933-04-01 00:00:00
# Calculating... 1933-05-01 00:00:00
# Calculating... 1933-06-01 00:00:00
# Calculating... 1933-07-01 00:00:00
# Calculating... 1933-08-01 00:00:00
# Calculating... 1933-09-01 00:00:00
# Calculating... 1933-10-01 00:00:00
# Calculating... 1933-11-01 00:00:00
# Calculating... 1933-12-01 00:00:00
# Calculating... 1934-01-01 00:00:00
# Calculating... 1934-02-01 00:00:00
# Calculating... 1934-03-01 00:00:00
# Calculating... 1934-04-01 00:00:00
# Calculating... 1934-05-01 00:00:00
# Calculating... 1934-06-01 00:00:00
# Calculating... 1934-07-01 00:00:00
# Calculating... 1934-08-01 00:00:00
# Calculating... 1934-09-01 00:00:00
# Calculating... 1934-10-01 00:00:00
# Calculating... 1934-11-01 00:00:00
# Calculating... 1934-12-01 00:00:00
# Calculating... 1935-01-01 00:00:00
# Calculating... 1935-02-01 00:00:00
# Calculating... 1935-03-01 00:00:00
# Calculating... 1935-04-01 00:00:00
# Calculating... 1935-05-01 00:00:00
# Calculating... 1935-06-01 00:00:00
# Calculating... 1935-07-01 00:00:00
# Calculating... 1935-08-01 00:00:00
# Calculating... 1935-09-01 00:00:00
# Calculating... 1935-10-01 00:00:00
# Calculating... 1935-11-01 00:00:00
# Calculating... 1935-12-01 00:00:00
# Calculating... 1936-01-01 00:00:00
# Calculating... 1936-02-01 00:00:00
# Calculating... 1936-03-01 00:00:00
# Calculating... 1936-04-01 00:00:00
# Calculating... 1936-05-01 00:00:00
# Calculating... 1936-06-01 00:00:00
# Calculating... 1936-07-01 00:00:00
# Calculating... 1936-08-01 00:00:00
# Calculating... 1936-09-01 00:00:00
# Calculating... 1936-10-01 00:00:00
# Calculating... 1936-11-01 00:00:00
# Calculating... 1936-12-01 00:00:00
# Calculating... 1937-01-01 00:00:00
# Calculating... 1937-02-01 00:00:00
# Calculating... 1937-03-01 00:00:00
# Calculating... 1937-04-01 00:00:00
# Calculating... 1937-05-01 00:00:00
# Calculating... 1937-06-01 00:00:00
# Calculating... 1937-07-01 00:00:00
# Calculating... 1937-08-01 00:00:00
# Calculating... 1937-09-01 00:00:00
# Calculating... 1937-10-01 00:00:00
# Calculating... 1937-11-01 00:00:00
# Calculating... 1937-12-01 00:00:00
# Calculating... 1938-01-01 00:00:00
# Calculating... 1938-02-01 00:00:00
# Calculating... 1938-03-01 00:00:00
# Calculating... 1938-04-01 00:00:00
# Calculating... 1938-05-01 00:00:00
# Calculating... 1938-06-01 00:00:00
# Calculating... 1938-07-01 00:00:00
# Calculating... 1938-08-01 00:00:00
# Calculating... 1938-09-01 00:00:00
# Calculating... 1938-10-01 00:00:00
# Calculating... 1938-11-01 00:00:00
# Calculating... 1938-12-01 00:00:00
# Calculating... 1939-01-01 00:00:00
# Calculating... 1939-02-01 00:00:00
# Calculating... 1939-03-01 00:00:00
# Calculating... 1939-04-01 00:00:00
# Calculating... 1939-05-01 00:00:00
# Calculating... 1939-06-01 00:00:00
# Calculating... 1939-07-01 00:00:00
# Calculating... 1939-08-01 00:00:00
# Calculating... 1939-09-01 00:00:00
# Calculating... 1939-10-01 00:00:00
# Calculating... 1939-11-01 00:00:00
# Calculating... 1939-12-01 00:00:00
# Calculating... 1940-01-01 00:00:00
# Calculating... 1940-02-01 00:00:00
# Calculating... 1940-03-01 00:00:00
# Calculating... 1940-04-01 00:00:00
# Calculating... 1940-05-01 00:00:00
# Calculating... 1940-06-01 00:00:00
# Calculating... 1940-07-01 00:00:00
# Calculating... 1940-08-01 00:00:00
# Calculating... 1940-09-01 00:00:00
# Calculating... 1940-10-01 00:00:00
# Calculating... 1940-11-01 00:00:00
# Calculating... 1940-12-01 00:00:00
# Calculating... 1941-01-01 00:00:00
# Calculating... 1941-02-01 00:00:00
# Calculating... 1941-03-01 00:00:00
# Calculating... 1941-04-01 00:00:00
# Calculating... 1941-05-01 00:00:00
# Calculating... 1941-06-01 00:00:00
# Calculating... 1941-07-01 00:00:00
# Calculating... 1941-08-01 00:00:00
# Calculating... 1941-09-01 00:00:00
# Calculating... 1941-10-01 00:00:00
# Calculating... 1941-11-01 00:00:00
# Calculating... 1941-12-01 00:00:00
# Calculating... 1942-01-01 00:00:00
# Calculating... 1942-02-01 00:00:00
# Calculating... 1942-03-01 00:00:00
# Calculating... 1942-04-01 00:00:00
# Calculating... 1942-05-01 00:00:00
# Calculating... 1942-06-01 00:00:00
# Calculating... 1942-07-01 00:00:00
# Calculating... 1942-08-01 00:00:00
# Calculating... 1942-09-01 00:00:00
# Calculating... 1942-10-01 00:00:00
# Calculating... 1942-11-01 00:00:00
# Calculating... 1942-12-01 00:00:00
# Calculating... 1943-01-01 00:00:00
# Calculating... 1943-02-01 00:00:00
# Calculating... 1943-03-01 00:00:00
# Calculating... 1943-04-01 00:00:00
# Calculating... 1943-05-01 00:00:00
# Calculating... 1943-06-01 00:00:00
# Calculating... 1943-07-01 00:00:00
# Calculating... 1943-08-01 00:00:00
# Calculating... 1943-09-01 00:00:00
# Calculating... 1943-10-01 00:00:00
# Calculating... 1943-11-01 00:00:00
# Calculating... 1943-12-01 00:00:00
# Calculating... 1944-01-01 00:00:00
# Calculating... 1944-02-01 00:00:00
# Calculating... 1944-03-01 00:00:00
# Calculating... 1944-04-01 00:00:00
# Calculating... 1944-05-01 00:00:00
# Calculating... 1944-06-01 00:00:00
# Calculating... 1944-07-01 00:00:00
# Calculating... 1944-08-01 00:00:00
# Calculating... 1944-09-01 00:00:00
# Calculating... 1944-10-01 00:00:00
# Calculating... 1944-11-01 00:00:00
# Calculating... 1944-12-01 00:00:00
# Calculating... 1945-01-01 00:00:00
# Calculating... 1945-02-01 00:00:00
# Calculating... 1945-03-01 00:00:00
# Calculating... 1945-04-01 00:00:00
# Calculating... 1945-05-01 00:00:00
# Calculating... 1945-06-01 00:00:00
# Calculating... 1945-07-01 00:00:00
# Calculating... 1945-08-01 00:00:00
# Calculating... 1945-09-01 00:00:00
# Calculating... 1945-10-01 00:00:00
# Calculating... 1945-11-01 00:00:00
# Calculating... 1945-12-01 00:00:00
# Calculating... 1946-01-01 00:00:00
# Calculating... 1946-02-01 00:00:00
# Calculating... 1946-03-01 00:00:00
# Calculating... 1946-04-01 00:00:00
# Calculating... 1946-05-01 00:00:00
# Calculating... 1946-06-01 00:00:00
# Calculating... 1946-07-01 00:00:00
# Calculating... 1946-08-01 00:00:00
# Calculating... 1946-09-01 00:00:00
# Calculating... 1946-10-01 00:00:00
# Calculating... 1946-11-01 00:00:00
# Calculating... 1946-12-01 00:00:00
# Calculating... 1947-01-01 00:00:00
# Calculating... 1947-02-01 00:00:00
# Calculating... 1947-03-01 00:00:00
# Calculating... 1947-04-01 00:00:00
# Calculating... 1947-05-01 00:00:00
# Calculating... 1947-06-01 00:00:00
# Calculating... 1947-07-01 00:00:00
# Calculating... 1947-08-01 00:00:00
# Calculating... 1947-09-01 00:00:00
# Calculating... 1947-10-01 00:00:00
# Calculating... 1947-11-01 00:00:00
# Calculating... 1947-12-01 00:00:00
# Calculating... 1948-01-01 00:00:00
# Calculating... 1948-02-01 00:00:00
# Calculating... 1948-03-01 00:00:00
# Calculating... 1948-04-01 00:00:00
# Calculating... 1948-05-01 00:00:00
# Calculating... 1948-06-01 00:00:00
# Calculating... 1948-07-01 00:00:00
# Calculating... 1948-08-01 00:00:00
# Calculating... 1948-09-01 00:00:00
# Calculating... 1948-10-01 00:00:00
# Calculating... 1948-11-01 00:00:00
# Calculating... 1948-12-01 00:00:00
# Calculating... 1949-01-01 00:00:00
# Calculating... 1949-02-01 00:00:00
# Calculating... 1949-03-01 00:00:00
# Calculating... 1949-04-01 00:00:00
# Calculating... 1949-05-01 00:00:00
# Calculating... 1949-06-01 00:00:00
# Calculating... 1949-07-01 00:00:00
# Calculating... 1949-08-01 00:00:00
# Calculating... 1949-09-01 00:00:00
# Calculating... 1949-10-01 00:00:00
# Calculating... 1949-11-01 00:00:00
# Calculating... 1949-12-01 00:00:00
# Calculating... 1950-01-01 00:00:00
# Calculating... 1950-02-01 00:00:00
# Calculating... 1950-03-01 00:00:00
# Calculating... 1950-04-01 00:00:00
# Calculating... 1950-05-01 00:00:00
# Calculating... 1950-06-01 00:00:00
# Calculating... 1950-07-01 00:00:00
# Calculating... 1950-08-01 00:00:00
# Calculating... 1950-09-01 00:00:00
# Calculating... 1950-10-01 00:00:00
# Calculating... 1950-11-01 00:00:00
# Calculating... 1950-12-01 00:00:00
# Calculating... 1951-01-01 00:00:00
# Calculating... 1951-02-01 00:00:00
# Calculating... 1951-03-01 00:00:00
# Calculating... 1951-04-01 00:00:00
# Calculating... 1951-05-01 00:00:00
# Calculating... 1951-06-01 00:00:00
# Calculating... 1951-07-01 00:00:00
# Calculating... 1951-08-01 00:00:00
# Calculating... 1951-09-01 00:00:00
# Calculating... 1951-10-01 00:00:00
# Calculating... 1951-11-01 00:00:00
# Calculating... 1951-12-01 00:00:00
# Calculating... 1952-01-01 00:00:00
# Calculating... 1952-02-01 00:00:00
# Calculating... 1952-03-01 00:00:00
# Calculating... 1952-04-01 00:00:00
# Calculating... 1952-05-01 00:00:00
# Calculating... 1952-06-01 00:00:00
# Calculating... 1952-07-01 00:00:00
# Calculating... 1952-08-01 00:00:00
# Calculating... 1952-09-01 00:00:00
# Calculating... 1952-10-01 00:00:00
# Calculating... 1952-11-01 00:00:00
# Calculating... 1952-12-01 00:00:00
# Calculating... 1953-01-01 00:00:00
# Calculating... 1953-02-01 00:00:00
# Calculating... 1953-03-01 00:00:00
# Calculating... 1953-04-01 00:00:00
# Calculating... 1953-05-01 00:00:00
# Calculating... 1953-06-01 00:00:00
# Calculating... 1953-07-01 00:00:00
# Calculating... 1953-08-01 00:00:00
# Calculating... 1953-09-01 00:00:00
# Calculating... 1953-10-01 00:00:00
# Calculating... 1953-11-01 00:00:00
# Calculating... 1953-12-01 00:00:00
# Calculating... 1954-01-01 00:00:00
# Calculating... 1954-02-01 00:00:00
# Calculating... 1954-03-01 00:00:00
# Calculating... 1954-04-01 00:00:00
# Calculating... 1954-05-01 00:00:00
# Calculating... 1954-06-01 00:00:00
# Calculating... 1954-07-01 00:00:00
# Calculating... 1954-08-01 00:00:00
# Calculating... 1954-09-01 00:00:00
# Calculating... 1954-10-01 00:00:00
# Calculating... 1954-11-01 00:00:00
# Calculating... 1954-12-01 00:00:00
# Calculating... 1955-01-01 00:00:00
# Calculating... 1955-02-01 00:00:00
# Calculating... 1955-03-01 00:00:00
# Calculating... 1955-04-01 00:00:00
# Calculating... 1955-05-01 00:00:00
# Calculating... 1955-06-01 00:00:00
# Calculating... 1955-07-01 00:00:00
# Calculating... 1955-08-01 00:00:00
# Calculating... 1955-09-01 00:00:00
# Calculating... 1955-10-01 00:00:00
# Calculating... 1955-11-01 00:00:00
# Calculating... 1955-12-01 00:00:00
# Calculating... 1956-01-01 00:00:00
# Calculating... 1956-02-01 00:00:00
# Calculating... 1956-03-01 00:00:00
# Calculating... 1956-04-01 00:00:00
# Calculating... 1956-05-01 00:00:00
# Calculating... 1956-06-01 00:00:00
# Calculating... 1956-07-01 00:00:00
# Calculating... 1956-08-01 00:00:00
# Calculating... 1956-09-01 00:00:00
# Calculating... 1956-10-01 00:00:00
# Calculating... 1956-11-01 00:00:00
# Calculating... 1956-12-01 00:00:00
# Calculating... 1957-01-01 00:00:00
# Calculating... 1957-02-01 00:00:00
# Calculating... 1957-03-01 00:00:00
# Calculating... 1957-04-01 00:00:00
# Calculating... 1957-05-01 00:00:00
# Calculating... 1957-06-01 00:00:00
# Calculating... 1957-07-01 00:00:00
# Calculating... 1957-08-01 00:00:00
# Calculating... 1957-09-01 00:00:00
# Calculating... 1957-10-01 00:00:00
# Calculating... 1957-11-01 00:00:00
# Calculating... 1957-12-01 00:00:00
# Calculating... 1958-01-01 00:00:00
# Calculating... 1958-02-01 00:00:00
# Calculating... 1958-03-01 00:00:00
# Calculating... 1958-04-01 00:00:00
# Calculating... 1958-05-01 00:00:00
# Calculating... 1958-06-01 00:00:00
# Calculating... 1958-07-01 00:00:00
# Calculating... 1958-08-01 00:00:00
# Calculating... 1958-09-01 00:00:00
# Calculating... 1958-10-01 00:00:00
# Calculating... 1958-11-01 00:00:00
# Calculating... 1958-12-01 00:00:00
# Calculating... 1959-01-01 00:00:00
# Calculating... 1959-02-01 00:00:00
# Calculating... 1959-03-01 00:00:00
# Calculating... 1959-04-01 00:00:00
# Calculating... 1959-05-01 00:00:00
# Calculating... 1959-06-01 00:00:00
# Calculating... 1959-07-01 00:00:00
# Calculating... 1959-08-01 00:00:00
# Calculating... 1959-09-01 00:00:00
# Calculating... 1959-10-01 00:00:00
# Calculating... 1959-11-01 00:00:00
# Calculating... 1959-12-01 00:00:00
# Calculating... 1960-01-01 00:00:00
# Calculating... 1960-02-01 00:00:00
# Calculating... 1960-03-01 00:00:00
# Calculating... 1960-04-01 00:00:00
# Calculating... 1960-05-01 00:00:00
# Calculating... 1960-06-01 00:00:00
# Calculating... 1960-07-01 00:00:00
# Calculating... 1960-08-01 00:00:00
# Calculating... 1960-09-01 00:00:00
# Calculating... 1960-10-01 00:00:00
# Calculating... 1960-11-01 00:00:00
# Calculating... 1960-12-01 00:00:00
# Calculating... 1961-01-01 00:00:00
# Calculating... 1961-02-01 00:00:00
# Calculating... 1961-03-01 00:00:00
# Calculating... 1961-04-01 00:00:00
# Calculating... 1961-05-01 00:00:00
# Calculating... 1961-06-01 00:00:00
# Calculating... 1961-07-01 00:00:00
# Calculating... 1961-08-01 00:00:00
# Calculating... 1961-09-01 00:00:00
# Calculating... 1961-10-01 00:00:00
# Calculating... 1961-11-01 00:00:00
# Calculating... 1961-12-01 00:00:00
# Calculating... 1962-01-01 00:00:00
# Calculating... 1962-02-01 00:00:00
# Calculating... 1962-03-01 00:00:00
# Calculating... 1962-04-01 00:00:00
# Calculating... 1962-05-01 00:00:00
# Calculating... 1962-06-01 00:00:00
# Calculating... 1962-07-01 00:00:00
# Calculating... 1962-08-01 00:00:00
# Calculating... 1962-09-01 00:00:00
# Calculating... 1962-10-01 00:00:00
# Calculating... 1962-11-01 00:00:00
# Calculating... 1962-12-01 00:00:00
# Calculating... 1963-01-01 00:00:00
# Calculating... 1963-02-01 00:00:00
# Calculating... 1963-03-01 00:00:00
# Calculating... 1963-04-01 00:00:00
# Calculating... 1963-05-01 00:00:00
# Calculating... 1963-06-01 00:00:00
# Calculating... 1963-07-01 00:00:00
# Calculating... 1963-08-01 00:00:00
# Calculating... 1963-09-01 00:00:00
# Calculating... 1963-10-01 00:00:00
# Calculating... 1963-11-01 00:00:00
# Calculating... 1963-12-01 00:00:00
# Calculating... 1964-01-01 00:00:00
# Calculating... 1964-02-01 00:00:00
# Calculating... 1964-03-01 00:00:00
# Calculating... 1964-04-01 00:00:00
# Calculating... 1964-05-01 00:00:00
# Calculating... 1964-06-01 00:00:00
# Calculating... 1964-07-01 00:00:00
# Calculating... 1964-08-01 00:00:00
# Calculating... 1964-09-01 00:00:00
# Calculating... 1964-10-01 00:00:00
# Calculating... 1964-11-01 00:00:00
# Calculating... 1964-12-01 00:00:00
# Calculating... 1965-01-01 00:00:00
# Calculating... 1965-02-01 00:00:00
# Calculating... 1965-03-01 00:00:00
# Calculating... 1965-04-01 00:00:00
# Calculating... 1965-05-01 00:00:00
# Calculating... 1965-06-01 00:00:00
# Calculating... 1965-07-01 00:00:00
# Calculating... 1965-08-01 00:00:00
# Calculating... 1965-09-01 00:00:00
# Calculating... 1965-10-01 00:00:00
# Calculating... 1965-11-01 00:00:00
# Calculating... 1965-12-01 00:00:00
# Calculating... 1966-01-01 00:00:00
# Calculating... 1966-02-01 00:00:00
# Calculating... 1966-03-01 00:00:00
# Calculating... 1966-04-01 00:00:00
# Calculating... 1966-05-01 00:00:00
# Calculating... 1966-06-01 00:00:00
# Calculating... 1966-07-01 00:00:00
# Calculating... 1966-08-01 00:00:00
# Calculating... 1966-09-01 00:00:00
# Calculating... 1966-10-01 00:00:00
# Calculating... 1966-11-01 00:00:00
# Calculating... 1966-12-01 00:00:00
# Calculating... 1967-01-01 00:00:00
# Calculating... 1967-02-01 00:00:00
# Calculating... 1967-03-01 00:00:00
# Calculating... 1967-04-01 00:00:00
# Calculating... 1967-05-01 00:00:00
# Calculating... 1967-06-01 00:00:00
# Calculating... 1967-07-01 00:00:00
# Calculating... 1967-08-01 00:00:00
# Calculating... 1967-09-01 00:00:00
# Calculating... 1967-10-01 00:00:00
# Calculating... 1967-11-01 00:00:00
# Calculating... 1967-12-01 00:00:00
# Calculating... 1968-01-01 00:00:00
# Calculating... 1968-02-01 00:00:00
# Calculating... 1968-03-01 00:00:00
# Calculating... 1968-04-01 00:00:00
# Calculating... 1968-05-01 00:00:00
# Calculating... 1968-06-01 00:00:00
# Calculating... 1968-07-01 00:00:00
# Calculating... 1968-08-01 00:00:00
# Calculating... 1968-09-01 00:00:00
# Calculating... 1968-10-01 00:00:00
# Calculating... 1968-11-01 00:00:00
# Calculating... 1968-12-01 00:00:00
# Calculating... 1969-01-01 00:00:00
# Calculating... 1969-02-01 00:00:00
# Calculating... 1969-03-01 00:00:00
# Calculating... 1969-04-01 00:00:00
# Calculating... 1969-05-01 00:00:00
# Calculating... 1969-06-01 00:00:00
# Calculating... 1969-07-01 00:00:00
# Calculating... 1969-08-01 00:00:00
# Calculating... 1969-09-01 00:00:00
# Calculating... 1969-10-01 00:00:00
# Calculating... 1969-11-01 00:00:00
# Calculating... 1969-12-01 00:00:00
# Calculating... 1970-01-01 00:00:00
# Calculating... 1970-02-01 00:00:00
# Calculating... 1970-03-01 00:00:00
# Calculating... 1970-04-01 00:00:00
# Calculating... 1970-05-01 00:00:00
# Calculating... 1970-06-01 00:00:00
# Calculating... 1970-07-01 00:00:00
# Calculating... 1970-08-01 00:00:00
# Calculating... 1970-09-01 00:00:00
# Calculating... 1970-10-01 00:00:00
# Calculating... 1970-11-01 00:00:00
# Calculating... 1970-12-01 00:00:00
# Calculating... 1971-01-01 00:00:00
# Calculating... 1971-02-01 00:00:00
# Calculating... 1971-03-01 00:00:00
# Calculating... 1971-04-01 00:00:00
# Calculating... 1971-05-01 00:00:00
# Calculating... 1971-06-01 00:00:00
# Calculating... 1971-07-01 00:00:00
# Calculating... 1971-08-01 00:00:00
# Calculating... 1971-09-01 00:00:00
# Calculating... 1971-10-01 00:00:00
# Calculating... 1971-11-01 00:00:00
# Calculating... 1971-12-01 00:00:00
# Calculating... 1972-01-01 00:00:00
# Calculating... 1972-02-01 00:00:00
# Calculating... 1972-03-01 00:00:00
# Calculating... 1972-04-01 00:00:00
# Calculating... 1972-05-01 00:00:00
# Calculating... 1972-06-01 00:00:00
# Calculating... 1972-07-01 00:00:00
# Calculating... 1972-08-01 00:00:00
# Calculating... 1972-09-01 00:00:00
# Calculating... 1972-10-01 00:00:00
# Calculating... 1972-11-01 00:00:00
# Calculating... 1972-12-01 00:00:00
# Calculating... 1973-01-01 00:00:00
# Calculating... 1973-02-01 00:00:00
# Calculating... 1973-03-01 00:00:00
# Calculating... 1973-04-01 00:00:00
# Calculating... 1973-05-01 00:00:00
# Calculating... 1973-06-01 00:00:00
# Calculating... 1973-07-01 00:00:00
# Calculating... 1973-08-01 00:00:00
# Calculating... 1973-09-01 00:00:00
# Calculating... 1973-10-01 00:00:00
# Calculating... 1973-11-01 00:00:00
# Calculating... 1973-12-01 00:00:00
# Calculating... 1974-01-01 00:00:00
# Calculating... 1974-02-01 00:00:00
# Calculating... 1974-03-01 00:00:00
# Calculating... 1974-04-01 00:00:00
# Calculating... 1974-05-01 00:00:00
# Calculating... 1974-06-01 00:00:00
# Calculating... 1974-07-01 00:00:00
# Calculating... 1974-08-01 00:00:00
# Calculating... 1974-09-01 00:00:00
# Calculating... 1974-10-01 00:00:00
# Calculating... 1974-11-01 00:00:00
# Calculating... 1974-12-01 00:00:00
# Calculating... 1975-01-01 00:00:00
# Calculating... 1975-02-01 00:00:00
# Calculating... 1975-03-01 00:00:00
# Calculating... 1975-04-01 00:00:00
# Calculating... 1975-05-01 00:00:00
# Calculating... 1975-06-01 00:00:00
# Calculating... 1975-07-01 00:00:00
# Calculating... 1975-08-01 00:00:00
# Calculating... 1975-09-01 00:00:00
# Calculating... 1975-10-01 00:00:00
# Calculating... 1975-11-01 00:00:00
# Calculating... 1975-12-01 00:00:00
# Calculating... 1976-01-01 00:00:00
# Calculating... 1976-02-01 00:00:00
# Calculating... 1976-03-01 00:00:00
# Calculating... 1976-04-01 00:00:00
# Calculating... 1976-05-01 00:00:00
# Calculating... 1976-06-01 00:00:00
# Calculating... 1976-07-01 00:00:00
# Calculating... 1976-08-01 00:00:00
# Calculating... 1976-09-01 00:00:00
# Calculating... 1976-10-01 00:00:00
# Calculating... 1976-11-01 00:00:00
# Calculating... 1976-12-01 00:00:00
# Calculating... 1977-01-01 00:00:00
# Calculating... 1977-02-01 00:00:00
# Calculating... 1977-03-01 00:00:00
# Calculating... 1977-04-01 00:00:00
# Calculating... 1977-05-01 00:00:00
# Calculating... 1977-06-01 00:00:00
# Calculating... 1977-07-01 00:00:00
# Calculating... 1977-08-01 00:00:00
# Calculating... 1977-09-01 00:00:00
# Calculating... 1977-10-01 00:00:00
# Calculating... 1977-11-01 00:00:00
# Calculating... 1977-12-01 00:00:00
# Calculating... 1978-01-01 00:00:00
# Calculating... 1978-02-01 00:00:00
# Calculating... 1978-03-01 00:00:00
# Calculating... 1978-04-01 00:00:00
# Calculating... 1978-05-01 00:00:00
# Calculating... 1978-06-01 00:00:00
# Calculating... 1978-07-01 00:00:00
# Calculating... 1978-08-01 00:00:00
# Calculating... 1978-09-01 00:00:00
# Calculating... 1978-10-01 00:00:00
# Calculating... 1978-11-01 00:00:00
# Calculating... 1978-12-01 00:00:00
# Calculating... 1979-01-01 00:00:00
# Calculating... 1979-02-01 00:00:00
# Calculating... 1979-03-01 00:00:00
# Calculating... 1979-04-01 00:00:00
# Calculating... 1979-05-01 00:00:00
# Calculating... 1979-06-01 00:00:00
# Calculating... 1979-07-01 00:00:00
# Calculating... 1979-08-01 00:00:00
# Calculating... 1979-09-01 00:00:00
# Calculating... 1979-10-01 00:00:00
# Calculating... 1979-11-01 00:00:00
# Calculating... 1979-12-01 00:00:00
# Calculating... 1980-01-01 00:00:00
# Calculating... 1980-02-01 00:00:00
# Calculating... 1980-03-01 00:00:00
# Calculating... 1980-04-01 00:00:00
# Calculating... 1980-05-01 00:00:00
# Calculating... 1980-06-01 00:00:00
# Calculating... 1980-07-01 00:00:00
# Calculating... 1980-08-01 00:00:00
# Calculating... 1980-09-01 00:00:00
# Calculating... 1980-10-01 00:00:00
# Calculating... 1980-11-01 00:00:00
# Calculating... 1980-12-01 00:00:00
# Calculating... 1981-01-01 00:00:00
# Calculating... 1981-02-01 00:00:00
# Calculating... 1981-03-01 00:00:00
# Calculating... 1981-04-01 00:00:00
# Calculating... 1981-05-01 00:00:00
# Calculating... 1981-06-01 00:00:00
# Calculating... 1981-07-01 00:00:00
# Calculating... 1981-08-01 00:00:00
# Calculating... 1981-09-01 00:00:00
# Calculating... 1981-10-01 00:00:00
# Calculating... 1981-11-01 00:00:00
# Calculating... 1981-12-01 00:00:00
# Calculating... 1982-01-01 00:00:00
# Calculating... 1982-02-01 00:00:00
# Calculating... 1982-03-01 00:00:00
# Calculating... 1982-04-01 00:00:00
# Calculating... 1982-05-01 00:00:00
# Calculating... 1982-06-01 00:00:00
# Calculating... 1982-07-01 00:00:00
# Calculating... 1982-08-01 00:00:00
# Calculating... 1982-09-01 00:00:00
# Calculating... 1982-10-01 00:00:00
# Calculating... 1982-11-01 00:00:00
# Calculating... 1982-12-01 00:00:00
# Calculating... 1983-01-01 00:00:00
# Calculating... 1983-02-01 00:00:00
# Calculating... 1983-03-01 00:00:00
# Calculating... 1983-04-01 00:00:00
# Calculating... 1983-05-01 00:00:00
# Calculating... 1983-06-01 00:00:00
# Calculating... 1983-07-01 00:00:00
# Calculating... 1983-08-01 00:00:00
# Calculating... 1983-09-01 00:00:00
# Calculating... 1983-10-01 00:00:00
# Calculating... 1983-11-01 00:00:00
# Calculating... 1983-12-01 00:00:00
# Calculating... 1984-01-01 00:00:00
# Calculating... 1984-02-01 00:00:00
# Calculating... 1984-03-01 00:00:00
# Calculating... 1984-04-01 00:00:00
# Calculating... 1984-05-01 00:00:00
# Calculating... 1984-06-01 00:00:00
# Calculating... 1984-07-01 00:00:00
# Calculating... 1984-08-01 00:00:00
# Calculating... 1984-09-01 00:00:00
# Calculating... 1984-10-01 00:00:00
# Calculating... 1984-11-01 00:00:00
# Calculating... 1984-12-01 00:00:00
# Calculating... 1985-01-01 00:00:00
# Calculating... 1985-02-01 00:00:00
# Calculating... 1985-03-01 00:00:00
# Calculating... 1985-04-01 00:00:00
# Calculating... 1985-05-01 00:00:00
# Calculating... 1985-06-01 00:00:00
# Calculating... 1985-07-01 00:00:00
# Calculating... 1985-08-01 00:00:00
# Calculating... 1985-09-01 00:00:00
# Calculating... 1985-10-01 00:00:00
# Calculating... 1985-11-01 00:00:00
# Calculating... 1985-12-01 00:00:00
# Calculating... 1986-01-01 00:00:00
# Calculating... 1986-02-01 00:00:00
# Calculating... 1986-03-01 00:00:00
# Calculating... 1986-04-01 00:00:00
# Calculating... 1986-05-01 00:00:00
# Calculating... 1986-06-01 00:00:00
# Calculating... 1986-07-01 00:00:00
# Calculating... 1986-08-01 00:00:00
# Calculating... 1986-09-01 00:00:00
# Calculating... 1986-10-01 00:00:00
# Calculating... 1986-11-01 00:00:00
# Calculating... 1986-12-01 00:00:00
# Calculating... 1987-01-01 00:00:00
# Calculating... 1987-02-01 00:00:00
# Calculating... 1987-03-01 00:00:00
# Calculating... 1987-04-01 00:00:00
# Calculating... 1987-05-01 00:00:00
# Calculating... 1987-06-01 00:00:00
# Calculating... 1987-07-01 00:00:00
# Calculating... 1987-08-01 00:00:00
# Calculating... 1987-09-01 00:00:00
# Calculating... 1987-10-01 00:00:00
# Calculating... 1987-11-01 00:00:00
# Calculating... 1987-12-01 00:00:00
# Calculating... 1988-01-01 00:00:00
# Calculating... 1988-02-01 00:00:00
# Calculating... 1988-03-01 00:00:00
# Calculating... 1988-04-01 00:00:00
# Calculating... 1988-05-01 00:00:00
# Calculating... 1988-06-01 00:00:00
# Calculating... 1988-07-01 00:00:00
# Calculating... 1988-08-01 00:00:00
# Calculating... 1988-09-01 00:00:00
# Calculating... 1988-10-01 00:00:00
# Calculating... 1988-11-01 00:00:00
# Calculating... 1988-12-01 00:00:00
# Calculating... 1989-01-01 00:00:00
# Calculating... 1989-02-01 00:00:00
# Calculating... 1989-03-01 00:00:00
# Calculating... 1989-04-01 00:00:00
# Calculating... 1989-05-01 00:00:00
# Calculating... 1989-06-01 00:00:00
# Calculating... 1989-07-01 00:00:00
# Calculating... 1989-08-01 00:00:00
# Calculating... 1989-09-01 00:00:00
# Calculating... 1989-10-01 00:00:00
# Calculating... 1989-11-01 00:00:00
# Calculating... 1989-12-01 00:00:00
# Calculating... 1990-01-01 00:00:00
# Calculating... 1990-02-01 00:00:00
# Calculating... 1990-03-01 00:00:00
# Calculating... 1990-04-01 00:00:00
# Calculating... 1990-05-01 00:00:00
# Calculating... 1990-06-01 00:00:00
# Calculating... 1990-07-01 00:00:00
# Calculating... 1990-08-01 00:00:00
# Calculating... 1990-09-01 00:00:00
# Calculating... 1990-10-01 00:00:00
# Calculating... 1990-11-01 00:00:00
# Calculating... 1990-12-01 00:00:00
# Calculating... 1991-01-01 00:00:00
# Calculating... 1991-02-01 00:00:00
# Calculating... 1991-03-01 00:00:00
# Calculating... 1991-04-01 00:00:00
# Calculating... 1991-05-01 00:00:00
# Calculating... 1991-06-01 00:00:00
# Calculating... 1991-07-01 00:00:00
# Calculating... 1991-08-01 00:00:00
# Calculating... 1991-09-01 00:00:00
# Calculating... 1991-10-01 00:00:00
# Calculating... 1991-11-01 00:00:00
# Calculating... 1991-12-01 00:00:00
# Calculating... 1992-01-01 00:00:00
# Calculating... 1992-02-01 00:00:00
# Calculating... 1992-03-01 00:00:00
# Calculating... 1992-04-01 00:00:00
# Calculating... 1992-05-01 00:00:00
# Calculating... 1992-06-01 00:00:00
# Calculating... 1992-07-01 00:00:00
# Calculating... 1992-08-01 00:00:00
# Calculating... 1992-09-01 00:00:00
# Calculating... 1992-10-01 00:00:00
# Calculating... 1992-11-01 00:00:00
# Calculating... 1992-12-01 00:00:00
# Calculating... 1993-01-01 00:00:00
# Calculating... 1993-02-01 00:00:00
# Calculating... 1993-03-01 00:00:00
# Calculating... 1993-04-01 00:00:00
# Calculating... 1993-05-01 00:00:00
# Calculating... 1993-06-01 00:00:00
# Calculating... 1993-07-01 00:00:00
# Calculating... 1993-08-01 00:00:00
# Calculating... 1993-09-01 00:00:00
# Calculating... 1993-10-01 00:00:00
# Calculating... 1993-11-01 00:00:00
# Calculating... 1993-12-01 00:00:00
# Calculating... 1994-01-01 00:00:00
# Calculating... 1994-02-01 00:00:00
# Calculating... 1994-03-01 00:00:00
# Calculating... 1994-04-01 00:00:00
# Calculating... 1994-05-01 00:00:00
# Calculating... 1994-06-01 00:00:00
# Calculating... 1994-07-01 00:00:00
# Calculating... 1994-08-01 00:00:00
# Calculating... 1994-09-01 00:00:00
# Calculating... 1994-10-01 00:00:00
# Calculating... 1994-11-01 00:00:00
# Calculating... 1994-12-01 00:00:00
# Calculating... 1995-01-01 00:00:00
# Calculating... 1995-02-01 00:00:00
# Calculating... 1995-03-01 00:00:00
# Calculating... 1995-04-01 00:00:00
# Calculating... 1995-05-01 00:00:00
# Calculating... 1995-06-01 00:00:00
# Calculating... 1995-07-01 00:00:00
# Calculating... 1995-08-01 00:00:00
# Calculating... 1995-09-01 00:00:00
# Calculating... 1995-10-01 00:00:00
# Calculating... 1995-11-01 00:00:00
# Calculating... 1995-12-01 00:00:00
# Calculating... 1996-01-01 00:00:00
# Calculating... 1996-02-01 00:00:00
# Calculating... 1996-03-01 00:00:00
# Calculating... 1996-04-01 00:00:00
# Calculating... 1996-05-01 00:00:00
# Calculating... 1996-06-01 00:00:00
# Calculating... 1996-07-01 00:00:00
# Calculating... 1996-08-01 00:00:00
# Calculating... 1996-09-01 00:00:00
# Calculating... 1996-10-01 00:00:00
# Calculating... 1996-11-01 00:00:00
# Calculating... 1996-12-01 00:00:00
# Calculating... 1997-01-01 00:00:00
# Calculating... 1997-02-01 00:00:00
# Calculating... 1997-03-01 00:00:00
# Calculating... 1997-04-01 00:00:00
# Calculating... 1997-05-01 00:00:00
# Calculating... 1997-06-01 00:00:00
# Calculating... 1997-07-01 00:00:00
# Calculating... 1997-08-01 00:00:00
# Calculating... 1997-09-01 00:00:00
# Calculating... 1997-10-01 00:00:00
# Calculating... 1997-11-01 00:00:00
# Calculating... 1997-12-01 00:00:00
# Calculating... 1998-01-01 00:00:00
# Calculating... 1998-02-01 00:00:00
# Calculating... 1998-03-01 00:00:00
# Calculating... 1998-04-01 00:00:00
# Calculating... 1998-05-01 00:00:00
# Calculating... 1998-06-01 00:00:00
# Calculating... 1998-07-01 00:00:00
# Calculating... 1998-08-01 00:00:00
# Calculating... 1998-09-01 00:00:00
# Calculating... 1998-10-01 00:00:00
# Calculating... 1998-11-01 00:00:00
# Calculating... 1998-12-01 00:00:00
# Calculating... 1999-01-01 00:00:00
# Calculating... 1999-02-01 00:00:00
# Calculating... 1999-03-01 00:00:00
# Calculating... 1999-04-01 00:00:00
# Calculating... 1999-05-01 00:00:00
# Calculating... 1999-06-01 00:00:00
# Calculating... 1999-07-01 00:00:00
# Calculating... 1999-08-01 00:00:00
# Calculating... 1999-09-01 00:00:00
# Calculating... 1999-10-01 00:00:00
# Calculating... 1999-11-01 00:00:00
# Calculating... 1999-12-01 00:00:00
# Calculating... 2000-01-01 00:00:00
# Calculating... 2000-02-01 00:00:00
# Calculating... 2000-03-01 00:00:00
# Calculating... 2000-04-01 00:00:00
# Calculating... 2000-05-01 00:00:00
# Calculating... 2000-06-01 00:00:00
# Calculating... 2000-07-01 00:00:00
# Calculating... 2000-08-01 00:00:00
# Calculating... 2000-09-01 00:00:00
# Calculating... 2000-10-01 00:00:00
# Calculating... 2000-11-01 00:00:00
# Calculating... 2000-12-01 00:00:00
# Calculating... 2001-01-01 00:00:00
# Calculating... 2001-02-01 00:00:00
# Calculating... 2001-03-01 00:00:00
# Calculating... 2001-04-01 00:00:00
# Calculating... 2001-05-01 00:00:00
# Calculating... 2001-06-01 00:00:00
# Calculating... 2001-07-01 00:00:00
# Calculating... 2001-08-01 00:00:00
# Calculating... 2001-09-01 00:00:00
# Calculating... 2001-10-01 00:00:00
# Calculating... 2001-11-01 00:00:00
# Calculating... 2001-12-01 00:00:00
# Calculating... 2002-01-01 00:00:00
# Calculating... 2002-02-01 00:00:00
# Calculating... 2002-03-01 00:00:00
# Calculating... 2002-04-01 00:00:00
# Calculating... 2002-05-01 00:00:00
# Calculating... 2002-06-01 00:00:00
# Calculating... 2002-07-01 00:00:00
# Calculating... 2002-08-01 00:00:00
# Calculating... 2002-09-01 00:00:00
# Calculating... 2002-10-01 00:00:00
# Calculating... 2002-11-01 00:00:00
# Calculating... 2002-12-01 00:00:00
# Calculating... 2003-01-01 00:00:00
# Calculating... 2003-02-01 00:00:00
# Calculating... 2003-03-01 00:00:00
# Calculating... 2003-04-01 00:00:00
# Calculating... 2003-05-01 00:00:00
# Calculating... 2003-06-01 00:00:00
# Calculating... 2003-07-01 00:00:00
# Calculating... 2003-08-01 00:00:00
# Calculating... 2003-09-01 00:00:00
# Calculating... 2003-10-01 00:00:00
# Calculating... 2003-11-01 00:00:00
# Calculating... 2003-12-01 00:00:00
# Calculating... 2004-01-01 00:00:00
# Calculating... 2004-02-01 00:00:00
# Calculating... 2004-03-01 00:00:00
# Calculating... 2004-04-01 00:00:00
# Calculating... 2004-05-01 00:00:00
# Calculating... 2004-06-01 00:00:00
# Calculating... 2004-07-01 00:00:00
# Calculating... 2004-08-01 00:00:00
# Calculating... 2004-09-01 00:00:00
# Calculating... 2004-10-01 00:00:00
# Calculating... 2004-11-01 00:00:00
# Calculating... 2004-12-01 00:00:00
# Calculating... 2005-01-01 00:00:00
# Calculating... 2005-02-01 00:00:00
# Calculating... 2005-03-01 00:00:00
# Calculating... 2005-04-01 00:00:00
# Calculating... 2005-05-01 00:00:00
# Calculating... 2005-06-01 00:00:00
# Calculating... 2005-07-01 00:00:00
# Calculating... 2005-08-01 00:00:00
# Calculating... 2005-09-01 00:00:00
# Calculating... 2005-10-01 00:00:00
# Calculating... 2005-11-01 00:00:00
# Calculating... 2005-12-01 00:00:00
# Calculating... 2006-01-01 00:00:00
# Calculating... 2006-02-01 00:00:00
# Calculating... 2006-03-01 00:00:00
# Calculating... 2006-04-01 00:00:00
# Calculating... 2006-05-01 00:00:00
# Calculating... 2006-06-01 00:00:00
# Calculating... 2006-07-01 00:00:00
# Calculating... 2006-08-01 00:00:00
# Calculating... 2006-09-01 00:00:00
# Calculating... 2006-10-01 00:00:00
# Calculating... 2006-11-01 00:00:00
# Calculating... 2006-12-01 00:00:00
# Calculating... 2007-01-01 00:00:00
# Calculating... 2007-02-01 00:00:00
# Calculating... 2007-03-01 00:00:00
# Calculating... 2007-04-01 00:00:00
# Calculating... 2007-05-01 00:00:00
# Calculating... 2007-06-01 00:00:00
# Calculating... 2007-07-01 00:00:00
# Calculating... 2007-08-01 00:00:00
# Calculating... 2007-09-01 00:00:00
# Calculating... 2007-10-01 00:00:00
# Calculating... 2007-11-01 00:00:00
# Calculating... 2007-12-01 00:00:00
# Calculating... 2008-01-01 00:00:00
# Calculating... 2008-02-01 00:00:00
# Calculating... 2008-03-01 00:00:00
# Calculating... 2008-04-01 00:00:00
# Calculating... 2008-05-01 00:00:00
# Calculating... 2008-06-01 00:00:00
# Calculating... 2008-07-01 00:00:00
# Calculating... 2008-08-01 00:00:00
# Calculating... 2008-09-01 00:00:00
# Calculating... 2008-10-01 00:00:00
# Calculating... 2008-11-01 00:00:00
# Calculating... 2008-12-01 00:00:00
# Calculating... 2009-01-01 00:00:00
# Calculating... 2009-02-01 00:00:00
# Calculating... 2009-03-01 00:00:00
# Calculating... 2009-04-01 00:00:00
# Calculating... 2009-05-01 00:00:00
# Calculating... 2009-06-01 00:00:00
# Calculating... 2009-07-01 00:00:00
# Calculating... 2009-08-01 00:00:00
# Calculating... 2009-09-01 00:00:00
# Calculating... 2009-10-01 00:00:00
# Calculating... 2009-11-01 00:00:00
# Calculating... 2009-12-01 00:00:00
# Calculating... 2010-01-01 00:00:00
# Calculating... 2010-02-01 00:00:00
# Calculating... 2010-03-01 00:00:00
# Calculating... 2010-04-01 00:00:00
# Calculating... 2010-05-01 00:00:00
# Calculating... 2010-06-01 00:00:00
# Calculating... 2010-07-01 00:00:00
# Calculating... 2010-08-01 00:00:00
# Calculating... 2010-09-01 00:00:00
# Calculating... 2010-10-01 00:00:00
# Calculating... 2010-11-01 00:00:00
# Calculating... 2010-12-01 00:00:00
# Calculating... 2011-01-01 00:00:00
# Calculating... 2011-02-01 00:00:00
# Calculating... 2011-03-01 00:00:00
# Calculating... 2011-04-01 00:00:00
# Calculating... 2011-05-01 00:00:00
# Calculating... 2011-06-01 00:00:00
# Calculating... 2011-07-01 00:00:00
# Calculating... 2011-08-01 00:00:00
# Calculating... 2011-09-01 00:00:00
# Calculating... 2011-10-01 00:00:00
# Calculating... 2011-11-01 00:00:00
# Calculating... 2011-12-01 00:00:00
# Calculating... 2012-01-01 00:00:00
# Calculating... 2012-02-01 00:00:00
# Calculating... 2012-03-01 00:00:00
# Calculating... 2012-04-01 00:00:00
# Calculating... 2012-05-01 00:00:00
# Calculating... 2012-06-01 00:00:00
# Calculating... 2012-07-01 00:00:00
# Calculating... 2012-08-01 00:00:00
# Calculating... 2012-09-01 00:00:00
# Calculating... 2012-10-01 00:00:00
# Calculating... 2012-11-01 00:00:00
# Calculating... 2012-12-01 00:00:00
# Calculating... 2013-01-01 00:00:00
# Calculating... 2013-02-01 00:00:00
# Calculating... 2013-03-01 00:00:00
# Calculating... 2013-04-01 00:00:00
# Calculating... 2013-05-01 00:00:00
# Calculating... 2013-06-01 00:00:00
# Calculating... 2013-07-01 00:00:00
# Calculating... 2013-08-01 00:00:00
# Calculating... 2013-09-01 00:00:00
# Calculating... 2013-10-01 00:00:00
# Calculating... 2013-11-01 00:00:00
# Calculating... 2013-12-01 00:00:00
# Calculating... 2014-01-01 00:00:00
# Calculating... 2014-02-01 00:00:00
# Calculating... 2014-03-01 00:00:00
# Calculating... 2014-04-01 00:00:00
# Calculating... 2014-05-01 00:00:00
# Calculating... 2014-06-01 00:00:00
# Calculating... 2014-07-01 00:00:00
# Calculating... 2014-08-01 00:00:00
# Calculating... 2014-09-01 00:00:00
# Calculating... 2014-10-01 00:00:00
# Calculating... 2014-11-01 00:00:00
# Calculating... 2014-12-01 00:00:00
# Calculating... 2015-01-01 00:00:00
# Calculating... 2015-02-01 00:00:00
# Calculating... 2015-03-01 00:00:00
# Calculating... 2015-04-01 00:00:00
# Calculating... 2015-05-01 00:00:00
# Calculating... 2015-06-01 00:00:00
# Calculating... 2015-07-01 00:00:00
# Calculating... 2015-08-01 00:00:00
# Calculating... 2015-09-01 00:00:00
# Calculating... 2015-10-01 00:00:00
# Calculating... 2015-11-01 00:00:00
# Calculating... 2015-12-01 00:00:00
# Calculating... 2016-01-01 00:00:00
# Calculating... 2016-02-01 00:00:00
# Calculating... 2016-03-01 00:00:00
# Calculating... 2016-04-01 00:00:00
# Calculating... 2016-05-01 00:00:00
# Calculating... 2016-06-01 00:00:00
# Calculating... 2016-07-01 00:00:00
# Calculating... 2016-08-01 00:00:00
# Calculating... 2016-09-01 00:00:00
# Calculating... 2016-10-01 00:00:00
# Calculating... 2016-11-01 00:00:00
# Calculating... 2016-12-01 00:00:00
#                     NAV    Change
# 1871-01-01  4231.170682  0.002011
# 1871-02-01  4239.679839  0.001984
# 1871-03-01  4248.091659  0.001957
# 1871-04-01  4256.405574  0.001930
# 1871-05-01  4264.621046  0.001903
# CPU times: user 16.1 s, sys: 305 ms, total: 16.4 s
# Wall time: 16.9 s

# %%
sim_results.to_csv('bonds-monthly.csv')

# %%
def get_morningstar(secid):
    url = 'http://mschart.morningstar.com/chartweb/defaultChart?type=getcc&secids=%s&dataid=8225&startdate=1900-01-01&enddate=2016-11-18&currency=&format=1' % secid
    expire_after = datetime.timedelta(days=3)
    session = requests_cache.CachedSession(cache_name='data-cache', backend='sqlite', expire_after=expire_after)

    # TODO: why doesn't this work!?!
    #r = session.get(url)
    r = requests.get(url)
    j = r.json()
    
    # The Morningstar data is pretty deeply nested....
    m = j['data']['r'][0]
    assert m['i'] == secid
    
    actual_data = m['t'][0]['d']
    # convert from strings to real data types
    as_dict = dict([(datetime.datetime.strptime(n['i'], '%Y-%m-%d'), float(n['v'])) for n in m['t'][0]['d']])
    
    # Strip out data?
    # Do we only want start of month, end of month, start of year, end of year, etc?
    s = pandas.Series(as_dict, name=secid)

    return s

barclays_index = get_morningstar('XIUSA000MJ')

# Use only final value for each calendar year
def annual(series):
    return series.groupby(by=lambda x: x.year).last()
# Use only final value for each calendar month
def monthly(series):
    return series.groupby(by=lambda x: datetime.date(x.year, x.month, 1)).last()

# %%
monthly_results = pandas.concat([sim_results, monthly(barclays_index)], axis=1, join='outer')

def calculate_change_prev(df, column):
    max_row = df.shape[0]
    
    series = pandas.Series()

    for i in range(max_row - 1):
        val = df.iloc[i][column]
        prev_val = df.iloc[i-1][column]
        change = (val - prev_val) / prev_val
        series.loc[df.iloc[i].name] = change
    return series

def calculate_change_next(df, column):
    max_row = df.shape[0]
    
    series = pandas.Series()

    for i in range(max_row - 1):
        val = df.iloc[i][column]
        next_val = df.iloc[i+1][column]
        change = (next_val - val) / val
        series.loc[df.iloc[i].name] = change
    return series


index_change = calculate_change_prev(monthly_results, 'XIUSA000MJ')
monthly_results = monthly_results.assign(index_change=index_change)
print(monthly_results[["Change", "index_change"]].corr())
# Out:
#                Change  index_change
# Change        1.00000       0.62899
# index_change  0.62899       1.00000

# %%
# This feels a bit messy & unclear. Do we count from December 31 to December 31? Or something else?
# TODO. Need to think more about this.
annual_results = monthly_results.groupby(by=lambda x: x.year).first()
s_nav = calculate_change_next(annual_results, 'NAV')
s_ind = calculate_change_next(annual_results, 'XIUSA000MJ')
annual_results = annual_results.assign(Change=s_nav, index_change=s_ind)
print(annual_results[["Change", "index_change"]].corr())
#annual_results.to_csv('check.csv')
# Out:
#                 Change  index_change
# Change        1.000000      0.900082
# index_change  0.900082      1.000000
